# %% [markdown]
# ## Stack exchange questions (with Paging)

# %% [markdown]
# ### 1. Import the Libraries

# %%
# Import Pandas, Requests, JSON and Time library
import pandas as pd
import requests
import json
import time

# %% [markdown]
# ### 2. Generate URL request, access its status code attribute and access data

# %%
# Response object returned from the API
response_API = requests.get("https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow")

# %%
# Print out the status code value
print(response_API.status_code)
# Out:
# 200

# %% [markdown]
# ### 3. Convert JSON string into Python object (Dictionary)

# %%
# JSON response of the JSON object of the result
response_json = response_API.json()

# Show the JSON response
response_json
# Out:
# {'items': [{'tags': ['reactjs', 'redux'],
#    'owner': {'account_id': 21317036,
#     'reputation': 29,
#     'user_id': 15690730,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a-/AOh14GhFpV6WzoCMNu5yZwTqfxzXibXYogD-yWPutF0-dQ=k-s128',
#     'display_name': 'Tim Taylor',
#     'link': 'https://stackoverflow.com/users/15690730/tim-taylor'},
#    'is_answered': False,
#    'view_count': 12,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1633126882,
#    'creation_date': 1633126243,
#    'last_edit_date': 1633126882,
#    'question_id': 69412410,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69412410/why-am-i-receiving-invalid-hook-call-error',
#    'title': 'Why am I receiving &#39;Invalid hook call&#39; error?'},
#   {'tags': ['javascript', 'reactjs', 'api', 'fetch'],
#    'owner': {'account_id': 20580108,
#     'reputation': 53,
#     'user_id': 15106423,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/BHdqr.jpg?s=128&g=1',
#     'display_name': 'sayinmehmet47',
#     'link': 'https://stackoverflow.com/users/15106423/sayinmehmet47'},
#    'is_answered': True,
#    'view_count': 41,
#    'accepted_answer_id': 69412270,
#    'answer_count': 4,
#    'score': 1,
#    'last_activity_date': 1633126878,
#    'creation_date': 1633119975,
#    'question_id': 69411652,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69411652/how-to-use-two-map-function-with-two-fetching-url',
#    'title': 'How to use two map function with two fetching url'},
#   {'tags': ['css'],
#    'owner': {'account_id': 5157897,
#     'reputation': 217,
#     'user_id': 4697686,
#     'user_type': 'registered',
#     'accept_rate': 17,
#     'profile_image': 'https://www.gravatar.com/avatar/0cbe0f9220a9ebc5d71f64b0e11b4e0d?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'dnraikes',
#     'link': 'https://stackoverflow.com/users/4697686/dnraikes'},
#    'is_answered': False,
#    'view_count': 8,
#    'answer_count': 1,
#    'score': 0,
#    'last_activity_date': 1633126877,
#    'creation_date': 1633126410,
#    'question_id': 69412432,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69412432/why-isnt-the-background-color-in-my-nav-region-correct',
#    'title': 'Why isn&#39;t the background color in my nav region correct'},
#   {'tags': ['javascript', 'jquery', 'html', 'arrays'],
#    'owner': {'account_id': 14434646,
#     'reputation': 109,
#     'user_id': 10426952,
#     'user_type': 'registered',
#     'profile_image': 'https://lh4.googleusercontent.com/-txyBGbcWxSE/AAAAAAAAAAI/AAAAAAAAAMo/7qDnfre4_rs/photo.jpg?sz=128',
#     'display_name': 'denis ',
#     'link': 'https://stackoverflow.com/users/10426952/denis'},
#    'is_answered': True,
#    'view_count': 43,
#    'closed_date': 1538109653,
#    'accepted_answer_id': 52547029,
#    'answer_count': 1,
#    'score': 1,
#    'last_activity_date': 1633126874,
#    'creation_date': 1538096250,
#    'last_edit_date': 1538112054,
#    'question_id': 52546895,
#    'link': 'https://stackoverflow.com/questions/52546895/shorthand-way-of-creating-html-elements-from-an-array-of-arrays',
#    'closed_reason': 'Needs more focus',
#    'title': 'Shorthand way of creating html elements from an array of arrays'},
#   {'tags': ['python', 'sql', 'python-3.x', 'sqlite', 'tkinter'],
#    'owner': {'account_id': 22753997,
#     'reputation': 25,
#     'user_id': 16913725,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/9f7ba5f683e3606b47cb49cce752c37c?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'William50694',
#     'link': 'https://stackoverflow.com/users/16913725/william50694'},
#    'is_answered': False,
#    'view_count': 17,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1633126873,
#    'creation_date': 1633123896,
#    'last_edit_date': 1633126873,
#    'question_id': 69412157,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69412157/problem-saving-field-in-database-insert-2-fields-from-a-single-combobox',
#    'title': 'Problem saving field in database: insert 2 fields from a single combobox?'},
#   {'tags': ['postgresql', 'database-design'],
#    'owner': {'account_id': 6515552,
#     'reputation': 1,
#     'user_id': 5041506,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/39ae92c402384b91d9b8c08d933129dd?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'montybeatnik',
#     'link': 'https://stackoverflow.com/users/5041506/montybeatnik'},
#    'is_answered': False,
#    'view_count': 1,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1633126872,
#    'creation_date': 1633126872,
#    'question_id': 69412480,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69412480/is-it-possible-to-build-a-table-of-device-interfaces-that-references-a-device-mo',
#    'title': 'Is it possible to build a table of device interfaces that references a device models table for consumption by a devices table?'},
#   {'tags': ['excel', 'vba', 'dropdown'],
#    'owner': {'account_id': 22024684,
#     'reputation': 33,
#     'user_id': 16292884,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/1ada24d738f5a09c219fc90aaf5edd02?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'wmspaul',
#     'link': 'https://stackoverflow.com/users/16292884/wmspaul'},
#    'is_answered': False,
#    'view_count': 12,
#    'answer_count': 2,
#    'score': 0,
#    'last_activity_date': 1633126858,
#    'creation_date': 1633123180,
#    'question_id': 69412074,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69412074/automatically-update-cells-with-dependent-dropdown-values',
#    'title': 'Automatically update cells with dependent dropdown values'},
#   {'tags': ['django', 'image', 'upload', 'tinymce', 'media'],
#    'owner': {'account_id': 4541292,
#     'reputation': 1,
#     'user_id': 3689100,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/c2885a3282a55757f2145e1516b18701?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'user3689100',
#     'link': 'https://stackoverflow.com/users/3689100/user3689100'},
#    'is_answered': False,
#    'view_count': 45,
#    'answer_count': 1,
#    'score': 0,
#    'last_activity_date': 1633126856,
#    'creation_date': 1606062225,
#    'question_id': 64956553,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/64956553/tinymce-with-digitalocean-space-in-django',
#    'title': 'TinyMCE with DigitalOcean Space in Django'},
#   {'tags': ['javascript', 'arrays', 'fizzbuzz'],
#    'owner': {'account_id': 22868049,
#     'reputation': 1,
#     'user_id': 17011521,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/0fce82c0eb7efc9c2bd5d750bd44b539?s=128&d=identicon&r=PG',
#     'display_name': 'caseyle',
#     'link': 'https://stackoverflow.com/users/17011521/caseyle'},
#    'is_answered': False,
#    'view_count': 22,
#    'answer_count': 2,
#    'score': 0,
#    'last_activity_date': 1633126842,
#    'creation_date': 1633126373,
#    'question_id': 69412424,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69412424/from-fizzbuzz-to-an-array',
#    'title': 'From FizzBuzz to an array'},
#   {'tags': ['report', 'data-visualization', 'google-data-studio'],
#    'owner': {'account_id': 22910974,
#     'reputation': 1,
#     'user_id': 17048243,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a/AATXAJxRw-uDnY2kpJlhiWIBhB4sxroUDZPPqahE8N-p=k-s128',
#     'display_name': 'Omar Rashed',
#     'link': 'https://stackoverflow.com/users/17048243/omar-rashed'},
#    'is_answered': False,
#    'view_count': 2,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1633126828,
#    'creation_date': 1633126828,
#    'question_id': 69412477,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69412477/google-data-studio-is-there-a-way-i-can-apply-changes-on-multiple-reports-simul',
#    'title': 'google data studio: is there a way I can apply changes on multiple reports simultaneously'},
#   {'tags': ['c#', 'asp.net-core', '.net-core', 'dependency-injection'],
#    'owner': {'account_id': 207495,
#     'reputation': 7900,
#     'user_id': 457392,
#     'user_type': 'registered',
#     'accept_rate': 48,
#     'profile_image': 'https://www.gravatar.com/avatar/75ac4fa755d77c846955d3c9ef39a9f9?s=128&d=identicon&r=PG',
#     'display_name': 'Andy',
#     'link': 'https://stackoverflow.com/users/457392/andy'},
#    'is_answered': True,
#    'view_count': 1865,
#    'accepted_answer_id': 61041725,
#    'answer_count': 3,
#    'score': 2,
#    'last_activity_date': 1633126825,
#    'creation_date': 1586083848,
#    'question_id': 61041416,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/61041416/asp-net-core-di-can-i-make-a-service-dependent-on-other-services',
#    'title': 'asp.net core DI - can I make a service dependent on other services'},
#   {'tags': ['mysql', 'laravel', 'datatable', 'server-side'],
#    'owner': {'account_id': 4746720,
#     'reputation': 915,
#     'user_id': 3837868,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/c085bb93d1a45cf81a6e0106438d8b73?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'user3837868',
#     'link': 'https://stackoverflow.com/users/3837868/user3837868'},
#    'is_answered': False,
#    'view_count': 148,
#    'bounty_amount': 50,
#    'bounty_closes_date': 1633163340,
#    'answer_count': 7,
#    'score': -1,
#    'last_activity_date': 1633126821,
#    'creation_date': 1632079435,
#    'last_edit_date': 1632893591,
#    'question_id': 69246427,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69246427/laravel-datatable-taking-too-much-of-time-to-load-data',
#    'title': 'Laravel datatable taking too much of time to load data'},
#   {'tags': ['android',
#     'qt',
#     'android-ndk',
#     'android-emulator',
#     'ubuntu-20.04'],
#    'owner': {'account_id': 13353562,
#     'reputation': 6584,
#     'user_id': 9638272,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/j0cSF.jpg?s=128&g=1',
#     'display_name': 'asmmo',
#     'link': 'https://stackoverflow.com/users/9638272/asmmo'},
#    'is_answered': False,
#    'view_count': 255,
#    'answer_count': 1,
#    'score': 0,
#    'last_activity_date': 1633126820,
#    'creation_date': 1616859846,
#    'last_edit_date': 1616860546,
#    'question_id': 66833153,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/66833153/couldnt-start-the-android-emulator-for-armv8-aarch64-and-armv7-architectures',
#    'title': 'Couldn&#39;t start the android-emulator for armv8-aarch64 and armv7 architectures'},
#   {'tags': ['php', 'wordpress', 'plugins', 'drop-down-menu'],
#    'owner': {'account_id': 22918598,
#     'reputation': 1,
#     'user_id': 17054794,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/86d521326574876d4ef5968a761cd2a8?s=128&d=identicon&r=PG',
#     'display_name': 'Ben',
#     'link': 'https://stackoverflow.com/users/17054794/ben'},
#    'is_answered': False,
#    'view_count': 2,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1633126812,
#    'creation_date': 1633126812,
#    'question_id': 69412474,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69412474/multiple-dropdown-select-wordpress',
#    'title': 'Multiple Dropdown Select WORDPRESS'},
#   {'tags': ['javascript', 'graph-theory', 'graph-algorithm', 'graph-coloring'],
#    'owner': {'account_id': 22918585,
#     'reputation': 1,
#     'user_id': 17054783,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a-/AOh14Gg6jf7DN1laskwDBO5OAUp31W0WwpR207n7UVCR=k-s128',
#     'display_name': 'itshimaru gen',
#     'link': 'https://stackoverflow.com/users/17054783/itshimaru-gen'},
#    'is_answered': False,
#    'view_count': 12,
#    'closed_date': 1633126667,
#    'answer_count': 0,
#    'score': -1,
#    'last_activity_date': 1633126812,
#    'creation_date': 1633126416,
#    'last_edit_date': 1633126812,
#    'question_id': 69412434,
#    'link': 'https://stackoverflow.com/questions/69412434/check-if-a-graph-is-2-colorable-in-javascript',
#    'closed_reason': 'Needs more focus',
#    'title': 'check if a graph is 2 colorable in javascript'},
#   {'tags': ['azure', 'salesforce', 'azure-data-factory'],
#    'owner': {'account_id': 8628160,
#     'reputation': 342,
#     'user_id': 6460715,
#     'user_type': 'registered',
#     'accept_rate': 88,
#     'profile_image': 'https://www.gravatar.com/avatar/dbd0136c8b5add705604842849c1bdd5?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'ahmed nader',
#     'link': 'https://stackoverflow.com/users/6460715/ahmed-nader'},
#    'is_answered': False,
#    'view_count': 7,
#    'answer_count': 1,
#    'score': 0,
#    'last_activity_date': 1633126811,
#    'creation_date': 1633117984,
#    'question_id': 69411346,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69411346/how-to-use-jwt-access-token-from-salesforce-with-azure-data-factory',
#    'title': 'How to use JWT access token from salesforce with azure data factory?'},
#   {'tags': ['ruby', 'api', 'rspec'],
#    'owner': {'account_id': 17881608,
#     'reputation': 39,
#     'user_id': 12990232,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/f823a5d15ada7acf33db489a83473c34?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Tadeu',
#     'link': 'https://stackoverflow.com/users/12990232/tadeu'},
#    'is_answered': False,
#    'view_count': 2,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1633126809,
#    'creation_date': 1633126809,
#    'question_id': 69412472,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69412472/i-cant-return-an-apis-body-with-ruby-and-rspec',
#    'title': 'I can&#39;t return an api&#39;s body with RUBY \u200band RSPEC'},
#   {'tags': ['python', 'pandas', 'matplotlib', 'colors', 'gradient'],
#    'owner': {'account_id': 22918534,
#     'reputation': 1,
#     'user_id': 17054743,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/20f401d905f58482051a054df7e1f201?s=128&d=identicon&r=PG',
#     'display_name': 'irrelevantt',
#     'link': 'https://stackoverflow.com/users/17054743/irrelevantt'},
#    'is_answered': False,
#    'view_count': 12,
#    'answer_count': 0,
#    'score': -3,
#    'last_activity_date': 1633126809,
#    'creation_date': 1633125459,
#    'last_edit_date': 1633126809,
#    'question_id': 69412339,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69412339/how-can-i-change-the-line-color-depending-on-the-gradient-of-another-line-in-mat',
#    'title': 'How can I change the line color depending on the gradient of another line in matplotlib?'},
#   {'tags': ['javascript', 'node.js', 'typescript', 'oauth-2.0', 'discord.js'],
#    'owner': {'account_id': 19313476,
#     'reputation': 17,
#     'user_id': 14118723,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/Qrbyz.jpg?s=128&g=1',
#     'display_name': 'Dominik Knaup',
#     'link': 'https://stackoverflow.com/users/14118723/dominik-knaup'},
#    'is_answered': False,
#    'view_count': 4,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1633126807,
#    'creation_date': 1633126807,
#    'question_id': 69412471,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69412471/how-can-i-fix-this-typescript-error-ts2339',
#    'title': 'how can i fix this typescript error TS2339?'},
#   {'tags': ['r', 'loops', 'vector', 'rstudio'],
#    'owner': {'account_id': 21839505,
#     'reputation': 1,
#     'user_id': 17054804,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/1162f243b2c84970d2f3dc8f42267757?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Alex',
#     'link': 'https://stackoverflow.com/users/17054804/alex'},
#    'is_answered': False,
#    'view_count': 6,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1633126806,
#    'creation_date': 1633126475,
#    'last_edit_date': 1633126806,
#    'question_id': 69412436,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69412436/how-do-i-use-a-loop-to-store-values-into-a-vector',
#    'title': 'How do I use a loop to store values into a vector?'},
#   {'tags': ['mysql', 'sql', 'sql-server'],
#    'owner': {'account_id': 21403024,
#     'reputation': 29,
#     'user_id': 15764730,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a-/AOh14GhHBzb_FaJqgUXS-dMrCu43ruOkdS1KUwWo2mxc=k-s128',
#     'display_name': 'Ansa Dhedhi',
#     'link': 'https://stackoverflow.com/users/15764730/ansa-dhedhi'},
#    'is_answered': False,
#    'view_count': 4,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1633126799,
#    'creation_date': 1633126799,
#    'question_id': 69412470,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69412470/sql-imaginary-data-solution',
#    'title': 'SQL Imaginary data Solution'},
#   {'tags': ['assembly', 'arm', 'gnu', 'gnu-assembler', 'thumb'],
#    'owner': {'account_id': 8736688,
#     'reputation': 33,
#     'user_id': 7997926,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/-9w5NI9HmaN4/AAAAAAAAAAI/AAAAAAAAAHA/PPOisDh7P6M/photo.jpg?sz=128',
#     'display_name': 'Renee Cousins',
#     'link': 'https://stackoverflow.com/users/7997926/renee-cousins'},
#    'is_answered': True,
#    'view_count': 34,
#    'accepted_answer_id': 69377292,
#    'answer_count': 1,
#    'score': 1,
#    'last_activity_date': 1633126773,
#    'creation_date': 1632918830,
#    'last_edit_date': 1633126773,
#    'question_id': 69376483,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69376483/dynamic-assembly-in-thumb-or-arm-mode',
#    'title': 'Dynamic assembly in THUMB or ARM mode'},
#   {'tags': ['ios', 'swift', 'webkit', 'wkwebview', 'uiwindow'],
#    'owner': {'account_id': 12267667,
#     'reputation': 146,
#     'user_id': 8953759,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/9b281508cff69e05da3b01aa98f1f319?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Mehmet Baykar',
#     'link': 'https://stackoverflow.com/users/8953759/mehmet-baykar'},
#    'is_answered': False,
#    'view_count': 11,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1633126766,
#    'creation_date': 1633120943,
#    'last_edit_date': 1633126766,
#    'question_id': 69411789,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69411789/wkwebview-does-not-receive-touch-events',
#    'title': 'WKWebView does not receive touch events'},
#   {'tags': ['python', 'apache-kafka'],
#    'owner': {'account_id': 2545829,
#     'reputation': 6768,
#     'user_id': 2210667,
#     'user_type': 'registered',
#     'accept_rate': 70,
#     'profile_image': 'https://www.gravatar.com/avatar/65e361318ee533712efd7929d6e9977c?s=128&d=identicon&r=PG',
#     'display_name': 'Thomas',
#     'link': 'https://stackoverflow.com/users/2210667/thomas'},
#    'is_answered': False,
#    'view_count': 8,
#    'answer_count': 1,
#    'score': 0,
#    'last_activity_date': 1633126756,
#    'creation_date': 1633124742,
#    'last_edit_date': 1633126691,
#    'question_id': 69412251,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69412251/why-would-a-replica-not-be-listed-as-a-kafka-broker',
#    'title': 'Why would a replica not be listed as a Kafka broker?'},
#   {'tags': ['omnet++', 'inet', 'passive-mode'],
#    'owner': {'account_id': 22685356,
#     'reputation': 1,
#     'user_id': 16855084,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a/AATXAJyLhbFyoWb0scje5zHak6kL6ZuyxDLB4Q4ZBCLV=k-s128',
#     'display_name': 'Safar Asaad',
#     'link': 'https://stackoverflow.com/users/16855084/safar-asaad'},
#    'is_answered': False,
#    'view_count': 3,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1633126754,
#    'creation_date': 1633126754,
#    'question_id': 69412468,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69412468/how-to-make-a-wifi-node-to-be-in-passive-monitoring-mode',
#    'title': 'How to make a WiFi node to be in passive monitoring mode?'},
#   {'tags': ['java', 'windows', 'batch-file', 'cmd', 'utf'],
#    'owner': {'account_id': 21934133,
#     'reputation': 1,
#     'user_id': 16215672,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a-/AOh14GgdUaaxXjsrwZ2qgWZ52rbYK-WD4sCP4wZ-jVkpxQ=k-s128',
#     'display_name': 'Andr&#233;s Kertesz',
#     'link': 'https://stackoverflow.com/users/16215672/andr%c3%a9s-kertesz'},
#    'is_answered': False,
#    'view_count': 3,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1633126740,
#    'creation_date': 1633126740,
#    'question_id': 69412467,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69412467/contents-within-a-bat-file-not-running-properly-when-running-said-bat-file',
#    'title': 'Contents within a .bat file not running properly when running said .bat file'},
#   {'tags': ['java', 'unit-testing', 'junit', 'mockito'],
#    'owner': {'account_id': 4260320,
#     'reputation': 313,
#     'user_id': 3484844,
#     'user_type': 'registered',
#     'accept_rate': 36,
#     'profile_image': 'https://www.gravatar.com/avatar/878e88a6d9188e4c17d30d8f5855595d?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Yellowjacket',
#     'link': 'https://stackoverflow.com/users/3484844/yellowjacket'},
#    'is_answered': False,
#    'view_count': 16,
#    'answer_count': 1,
#    'score': 0,
#    'last_activity_date': 1633126736,
#    'creation_date': 1633112411,
#    'question_id': 69410418,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69410418/mock-final-method-in-superclass',
#    'title': 'Mock final method in superclass'},
#   {'tags': ['javascript'],
#    'owner': {'user_type': 'does_not_exist', 'display_name': 'user7319004'},
#    'is_answered': True,
#    'view_count': 45,
#    'accepted_answer_id': 56201221,
#    'answer_count': 4,
#    'score': 1,
#    'last_activity_date': 1633126734,
#    'creation_date': 1558198917,
#    'last_edit_date': 1558199221,
#    'question_id': 56201093,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/56201093/find-unique-properties-in-array-and-calculate-matching-items',
#    'title': 'Find unique properties in array and calculate matching items'},
#   {'tags': ['python'],
#    'owner': {'account_id': 11682107,
#     'reputation': 139,
#     'user_id': 13259521,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/564298cb174153ef0422727046150862?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'GNZ',
#     'link': 'https://stackoverflow.com/users/13259521/gnz'},
#    'is_answered': False,
#    'view_count': 11,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1633126727,
#    'creation_date': 1633126727,
#    'question_id': 69412465,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69412465/how-to-find-indexes-at-once-in-python-this-case',
#    'title': 'How to find indexes at once in Python this case?'},
#   {'tags': ['python', 'discord', 'discord.py', 'bots'],
#    'owner': {'account_id': 22810526,
#     'reputation': 1,
#     'user_id': 16961905,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a-/AOh14GjiW2ZEK0Y5H93woaUA_N6fliW0LFM_gzOE_OUetA=k-s128',
#     'display_name': 'Secretcode',
#     'link': 'https://stackoverflow.com/users/16961905/secretcode'},
#    'is_answered': False,
#    'view_count': 22,
#    'answer_count': 1,
#    'score': 0,
#    'last_activity_date': 1633126725,
#    'creation_date': 1633120612,
#    'question_id': 69411740,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69411740/discord-python-kick-function-not-working-after-a-certain-time',
#    'title': 'Discord Python Kick Function not working after a certain time'}],
#  'has_more': True,
#  'quota_max': 300,
#  'quota_remaining': 96}

# %%
# Show the Keys of the Dictionary as a List
response_json.keys()
# Out:
# dict_keys(['items', 'has_more', 'quota_max', 'quota_remaining'])

# %%
# Show the Value of the Key ('items') of the Dictionary as a List
response_json['items']
# Out:
# [{'tags': ['reactjs', 'redux'],
#   'owner': {'account_id': 21317036,
#    'reputation': 29,
#    'user_id': 15690730,
#    'user_type': 'registered',
#    'profile_image': 'https://lh3.googleusercontent.com/a-/AOh14GhFpV6WzoCMNu5yZwTqfxzXibXYogD-yWPutF0-dQ=k-s128',
#    'display_name': 'Tim Taylor',
#    'link': 'https://stackoverflow.com/users/15690730/tim-taylor'},
#   'is_answered': False,
#   'view_count': 12,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1633126882,
#   'creation_date': 1633126243,
#   'last_edit_date': 1633126882,
#   'question_id': 69412410,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/69412410/why-am-i-receiving-invalid-hook-call-error',
#   'title': 'Why am I receiving &#39;Invalid hook call&#39; error?'},
#  {'tags': ['javascript', 'reactjs', 'api', 'fetch'],
#   'owner': {'account_id': 20580108,
#    'reputation': 53,
#    'user_id': 15106423,
#    'user_type': 'registered',
#    'profile_image': 'https://i.stack.imgur.com/BHdqr.jpg?s=128&g=1',
#    'display_name': 'sayinmehmet47',
#    'link': 'https://stackoverflow.com/users/15106423/sayinmehmet47'},
#   'is_answered': True,
#   'view_count': 41,
#   'accepted_answer_id': 69412270,
#   'answer_count': 4,
#   'score': 1,
#   'last_activity_date': 1633126878,
#   'creation_date': 1633119975,
#   'question_id': 69411652,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/69411652/how-to-use-two-map-function-with-two-fetching-url',
#   'title': 'How to use two map function with two fetching url'},
#  {'tags': ['css'],
#   'owner': {'account_id': 5157897,
#    'reputation': 217,
#    'user_id': 4697686,
#    'user_type': 'registered',
#    'accept_rate': 17,
#    'profile_image': 'https://www.gravatar.com/avatar/0cbe0f9220a9ebc5d71f64b0e11b4e0d?s=128&d=identicon&r=PG&f=1',
#    'display_name': 'dnraikes',
#    'link': 'https://stackoverflow.com/users/4697686/dnraikes'},
#   'is_answered': False,
#   'view_count': 8,
#   'answer_count': 1,
#   'score': 0,
#   'last_activity_date': 1633126877,
#   'creation_date': 1633126410,
#   'question_id': 69412432,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/69412432/why-isnt-the-background-color-in-my-nav-region-correct',
#   'title': 'Why isn&#39;t the background color in my nav region correct'},
#  {'tags': ['javascript', 'jquery', 'html', 'arrays'],
#   'owner': {'account_id': 14434646,
#    'reputation': 109,
#    'user_id': 10426952,
#    'user_type': 'registered',
#    'profile_image': 'https://lh4.googleusercontent.com/-txyBGbcWxSE/AAAAAAAAAAI/AAAAAAAAAMo/7qDnfre4_rs/photo.jpg?sz=128',
#    'display_name': 'denis ',
#    'link': 'https://stackoverflow.com/users/10426952/denis'},
#   'is_answered': True,
#   'view_count': 43,
#   'closed_date': 1538109653,
#   'accepted_answer_id': 52547029,
#   'answer_count': 1,
#   'score': 1,
#   'last_activity_date': 1633126874,
#   'creation_date': 1538096250,
#   'last_edit_date': 1538112054,
#   'question_id': 52546895,
#   'link': 'https://stackoverflow.com/questions/52546895/shorthand-way-of-creating-html-elements-from-an-array-of-arrays',
#   'closed_reason': 'Needs more focus',
#   'title': 'Shorthand way of creating html elements from an array of arrays'},
#  {'tags': ['python', 'sql', 'python-3.x', 'sqlite', 'tkinter'],
#   'owner': {'account_id': 22753997,
#    'reputation': 25,
#    'user_id': 16913725,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/9f7ba5f683e3606b47cb49cce752c37c?s=128&d=identicon&r=PG&f=1',
#    'display_name': 'William50694',
#    'link': 'https://stackoverflow.com/users/16913725/william50694'},
#   'is_answered': False,
#   'view_count': 17,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1633126873,
#   'creation_date': 1633123896,
#   'last_edit_date': 1633126873,
#   'question_id': 69412157,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/69412157/problem-saving-field-in-database-insert-2-fields-from-a-single-combobox',
#   'title': 'Problem saving field in database: insert 2 fields from a single combobox?'},
#  {'tags': ['postgresql', 'database-design'],
#   'owner': {'account_id': 6515552,
#    'reputation': 1,
#    'user_id': 5041506,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/39ae92c402384b91d9b8c08d933129dd?s=128&d=identicon&r=PG&f=1',
#    'display_name': 'montybeatnik',
#    'link': 'https://stackoverflow.com/users/5041506/montybeatnik'},
#   'is_answered': False,
#   'view_count': 1,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1633126872,
#   'creation_date': 1633126872,
#   'question_id': 69412480,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/69412480/is-it-possible-to-build-a-table-of-device-interfaces-that-references-a-device-mo',
#   'title': 'Is it possible to build a table of device interfaces that references a device models table for consumption by a devices table?'},
#  {'tags': ['excel', 'vba', 'dropdown'],
#   'owner': {'account_id': 22024684,
#    'reputation': 33,
#    'user_id': 16292884,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/1ada24d738f5a09c219fc90aaf5edd02?s=128&d=identicon&r=PG&f=1',
#    'display_name': 'wmspaul',
#    'link': 'https://stackoverflow.com/users/16292884/wmspaul'},
#   'is_answered': False,
#   'view_count': 12,
#   'answer_count': 2,
#   'score': 0,
#   'last_activity_date': 1633126858,
#   'creation_date': 1633123180,
#   'question_id': 69412074,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/69412074/automatically-update-cells-with-dependent-dropdown-values',
#   'title': 'Automatically update cells with dependent dropdown values'},
#  {'tags': ['django', 'image', 'upload', 'tinymce', 'media'],
#   'owner': {'account_id': 4541292,
#    'reputation': 1,
#    'user_id': 3689100,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/c2885a3282a55757f2145e1516b18701?s=128&d=identicon&r=PG&f=1',
#    'display_name': 'user3689100',
#    'link': 'https://stackoverflow.com/users/3689100/user3689100'},
#   'is_answered': False,
#   'view_count': 45,
#   'answer_count': 1,
#   'score': 0,
#   'last_activity_date': 1633126856,
#   'creation_date': 1606062225,
#   'question_id': 64956553,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/64956553/tinymce-with-digitalocean-space-in-django',
#   'title': 'TinyMCE with DigitalOcean Space in Django'},
#  {'tags': ['javascript', 'arrays', 'fizzbuzz'],
#   'owner': {'account_id': 22868049,
#    'reputation': 1,
#    'user_id': 17011521,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/0fce82c0eb7efc9c2bd5d750bd44b539?s=128&d=identicon&r=PG',
#    'display_name': 'caseyle',
#    'link': 'https://stackoverflow.com/users/17011521/caseyle'},
#   'is_answered': False,
#   'view_count': 22,
#   'answer_count': 2,
#   'score': 0,
#   'last_activity_date': 1633126842,
#   'creation_date': 1633126373,
#   'question_id': 69412424,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/69412424/from-fizzbuzz-to-an-array',
#   'title': 'From FizzBuzz to an array'},
#  {'tags': ['report', 'data-visualization', 'google-data-studio'],
#   'owner': {'account_id': 22910974,
#    'reputation': 1,
#    'user_id': 17048243,
#    'user_type': 'registered',
#    'profile_image': 'https://lh3.googleusercontent.com/a/AATXAJxRw-uDnY2kpJlhiWIBhB4sxroUDZPPqahE8N-p=k-s128',
#    'display_name': 'Omar Rashed',
#    'link': 'https://stackoverflow.com/users/17048243/omar-rashed'},
#   'is_answered': False,
#   'view_count': 2,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1633126828,
#   'creation_date': 1633126828,
#   'question_id': 69412477,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/69412477/google-data-studio-is-there-a-way-i-can-apply-changes-on-multiple-reports-simul',
#   'title': 'google data studio: is there a way I can apply changes on multiple reports simultaneously'},
#  {'tags': ['c#', 'asp.net-core', '.net-core', 'dependency-injection'],
#   'owner': {'account_id': 207495,
#    'reputation': 7900,
#    'user_id': 457392,
#    'user_type': 'registered',
#    'accept_rate': 48,
#    'profile_image': 'https://www.gravatar.com/avatar/75ac4fa755d77c846955d3c9ef39a9f9?s=128&d=identicon&r=PG',
#    'display_name': 'Andy',
#    'link': 'https://stackoverflow.com/users/457392/andy'},
#   'is_answered': True,
#   'view_count': 1865,
#   'accepted_answer_id': 61041725,
#   'answer_count': 3,
#   'score': 2,
#   'last_activity_date': 1633126825,
#   'creation_date': 1586083848,
#   'question_id': 61041416,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/61041416/asp-net-core-di-can-i-make-a-service-dependent-on-other-services',
#   'title': 'asp.net core DI - can I make a service dependent on other services'},
#  {'tags': ['mysql', 'laravel', 'datatable', 'server-side'],
#   'owner': {'account_id': 4746720,
#    'reputation': 915,
#    'user_id': 3837868,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/c085bb93d1a45cf81a6e0106438d8b73?s=128&d=identicon&r=PG&f=1',
#    'display_name': 'user3837868',
#    'link': 'https://stackoverflow.com/users/3837868/user3837868'},
#   'is_answered': False,
#   'view_count': 148,
#   'bounty_amount': 50,
#   'bounty_closes_date': 1633163340,
#   'answer_count': 7,
#   'score': -1,
#   'last_activity_date': 1633126821,
#   'creation_date': 1632079435,
#   'last_edit_date': 1632893591,
#   'question_id': 69246427,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/69246427/laravel-datatable-taking-too-much-of-time-to-load-data',
#   'title': 'Laravel datatable taking too much of time to load data'},
#  {'tags': ['android', 'qt', 'android-ndk', 'android-emulator', 'ubuntu-20.04'],
#   'owner': {'account_id': 13353562,
#    'reputation': 6584,
#    'user_id': 9638272,
#    'user_type': 'registered',
#    'profile_image': 'https://i.stack.imgur.com/j0cSF.jpg?s=128&g=1',
#    'display_name': 'asmmo',
#    'link': 'https://stackoverflow.com/users/9638272/asmmo'},
#   'is_answered': False,
#   'view_count': 255,
#   'answer_count': 1,
#   'score': 0,
#   'last_activity_date': 1633126820,
#   'creation_date': 1616859846,
#   'last_edit_date': 1616860546,
#   'question_id': 66833153,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/66833153/couldnt-start-the-android-emulator-for-armv8-aarch64-and-armv7-architectures',
#   'title': 'Couldn&#39;t start the android-emulator for armv8-aarch64 and armv7 architectures'},
#  {'tags': ['php', 'wordpress', 'plugins', 'drop-down-menu'],
#   'owner': {'account_id': 22918598,
#    'reputation': 1,
#    'user_id': 17054794,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/86d521326574876d4ef5968a761cd2a8?s=128&d=identicon&r=PG',
#    'display_name': 'Ben',
#    'link': 'https://stackoverflow.com/users/17054794/ben'},
#   'is_answered': False,
#   'view_count': 2,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1633126812,
#   'creation_date': 1633126812,
#   'question_id': 69412474,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/69412474/multiple-dropdown-select-wordpress',
#   'title': 'Multiple Dropdown Select WORDPRESS'},
#  {'tags': ['javascript', 'graph-theory', 'graph-algorithm', 'graph-coloring'],
#   'owner': {'account_id': 22918585,
#    'reputation': 1,
#    'user_id': 17054783,
#    'user_type': 'registered',
#    'profile_image': 'https://lh3.googleusercontent.com/a-/AOh14Gg6jf7DN1laskwDBO5OAUp31W0WwpR207n7UVCR=k-s128',
#    'display_name': 'itshimaru gen',
#    'link': 'https://stackoverflow.com/users/17054783/itshimaru-gen'},
#   'is_answered': False,
#   'view_count': 12,
#   'closed_date': 1633126667,
#   'answer_count': 0,
#   'score': -1,
#   'last_activity_date': 1633126812,
#   'creation_date': 1633126416,
#   'last_edit_date': 1633126812,
#   'question_id': 69412434,
#   'link': 'https://stackoverflow.com/questions/69412434/check-if-a-graph-is-2-colorable-in-javascript',
#   'closed_reason': 'Needs more focus',
#   'title': 'check if a graph is 2 colorable in javascript'},
#  {'tags': ['azure', 'salesforce', 'azure-data-factory'],
#   'owner': {'account_id': 8628160,
#    'reputation': 342,
#    'user_id': 6460715,
#    'user_type': 'registered',
#    'accept_rate': 88,
#    'profile_image': 'https://www.gravatar.com/avatar/dbd0136c8b5add705604842849c1bdd5?s=128&d=identicon&r=PG&f=1',
#    'display_name': 'ahmed nader',
#    'link': 'https://stackoverflow.com/users/6460715/ahmed-nader'},
#   'is_answered': False,
#   'view_count': 7,
#   'answer_count': 1,
#   'score': 0,
#   'last_activity_date': 1633126811,
#   'creation_date': 1633117984,
#   'question_id': 69411346,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/69411346/how-to-use-jwt-access-token-from-salesforce-with-azure-data-factory',
#   'title': 'How to use JWT access token from salesforce with azure data factory?'},
#  {'tags': ['ruby', 'api', 'rspec'],
#   'owner': {'account_id': 17881608,
#    'reputation': 39,
#    'user_id': 12990232,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/f823a5d15ada7acf33db489a83473c34?s=128&d=identicon&r=PG&f=1',
#    'display_name': 'Tadeu',
#    'link': 'https://stackoverflow.com/users/12990232/tadeu'},
#   'is_answered': False,
#   'view_count': 2,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1633126809,
#   'creation_date': 1633126809,
#   'question_id': 69412472,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/69412472/i-cant-return-an-apis-body-with-ruby-and-rspec',
#   'title': 'I can&#39;t return an api&#39;s body with RUBY \u200band RSPEC'},
#  {'tags': ['python', 'pandas', 'matplotlib', 'colors', 'gradient'],
#   'owner': {'account_id': 22918534,
#    'reputation': 1,
#    'user_id': 17054743,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/20f401d905f58482051a054df7e1f201?s=128&d=identicon&r=PG',
#    'display_name': 'irrelevantt',
#    'link': 'https://stackoverflow.com/users/17054743/irrelevantt'},
#   'is_answered': False,
#   'view_count': 12,
#   'answer_count': 0,
#   'score': -3,
#   'last_activity_date': 1633126809,
#   'creation_date': 1633125459,
#   'last_edit_date': 1633126809,
#   'question_id': 69412339,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/69412339/how-can-i-change-the-line-color-depending-on-the-gradient-of-another-line-in-mat',
#   'title': 'How can I change the line color depending on the gradient of another line in matplotlib?'},
#  {'tags': ['javascript', 'node.js', 'typescript', 'oauth-2.0', 'discord.js'],
#   'owner': {'account_id': 19313476,
#    'reputation': 17,
#    'user_id': 14118723,
#    'user_type': 'registered',
#    'profile_image': 'https://i.stack.imgur.com/Qrbyz.jpg?s=128&g=1',
#    'display_name': 'Dominik Knaup',
#    'link': 'https://stackoverflow.com/users/14118723/dominik-knaup'},
#   'is_answered': False,
#   'view_count': 4,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1633126807,
#   'creation_date': 1633126807,
#   'question_id': 69412471,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/69412471/how-can-i-fix-this-typescript-error-ts2339',
#   'title': 'how can i fix this typescript error TS2339?'},
#  {'tags': ['r', 'loops', 'vector', 'rstudio'],
#   'owner': {'account_id': 21839505,
#    'reputation': 1,
#    'user_id': 17054804,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/1162f243b2c84970d2f3dc8f42267757?s=128&d=identicon&r=PG&f=1',
#    'display_name': 'Alex',
#    'link': 'https://stackoverflow.com/users/17054804/alex'},
#   'is_answered': False,
#   'view_count': 6,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1633126806,
#   'creation_date': 1633126475,
#   'last_edit_date': 1633126806,
#   'question_id': 69412436,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/69412436/how-do-i-use-a-loop-to-store-values-into-a-vector',
#   'title': 'How do I use a loop to store values into a vector?'},
#  {'tags': ['mysql', 'sql', 'sql-server'],
#   'owner': {'account_id': 21403024,
#    'reputation': 29,
#    'user_id': 15764730,
#    'user_type': 'registered',
#    'profile_image': 'https://lh3.googleusercontent.com/a-/AOh14GhHBzb_FaJqgUXS-dMrCu43ruOkdS1KUwWo2mxc=k-s128',
#    'display_name': 'Ansa Dhedhi',
#    'link': 'https://stackoverflow.com/users/15764730/ansa-dhedhi'},
#   'is_answered': False,
#   'view_count': 4,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1633126799,
#   'creation_date': 1633126799,
#   'question_id': 69412470,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/69412470/sql-imaginary-data-solution',
#   'title': 'SQL Imaginary data Solution'},
#  {'tags': ['assembly', 'arm', 'gnu', 'gnu-assembler', 'thumb'],
#   'owner': {'account_id': 8736688,
#    'reputation': 33,
#    'user_id': 7997926,
#    'user_type': 'registered',
#    'profile_image': 'https://lh3.googleusercontent.com/-9w5NI9HmaN4/AAAAAAAAAAI/AAAAAAAAAHA/PPOisDh7P6M/photo.jpg?sz=128',
#    'display_name': 'Renee Cousins',
#    'link': 'https://stackoverflow.com/users/7997926/renee-cousins'},
#   'is_answered': True,
#   'view_count': 34,
#   'accepted_answer_id': 69377292,
#   'answer_count': 1,
#   'score': 1,
#   'last_activity_date': 1633126773,
#   'creation_date': 1632918830,
#   'last_edit_date': 1633126773,
#   'question_id': 69376483,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/69376483/dynamic-assembly-in-thumb-or-arm-mode',
#   'title': 'Dynamic assembly in THUMB or ARM mode'},
#  {'tags': ['ios', 'swift', 'webkit', 'wkwebview', 'uiwindow'],
#   'owner': {'account_id': 12267667,
#    'reputation': 146,
#    'user_id': 8953759,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/9b281508cff69e05da3b01aa98f1f319?s=128&d=identicon&r=PG&f=1',
#    'display_name': 'Mehmet Baykar',
#    'link': 'https://stackoverflow.com/users/8953759/mehmet-baykar'},
#   'is_answered': False,
#   'view_count': 11,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1633126766,
#   'creation_date': 1633120943,
#   'last_edit_date': 1633126766,
#   'question_id': 69411789,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/69411789/wkwebview-does-not-receive-touch-events',
#   'title': 'WKWebView does not receive touch events'},
#  {'tags': ['python', 'apache-kafka'],
#   'owner': {'account_id': 2545829,
#    'reputation': 6768,
#    'user_id': 2210667,
#    'user_type': 'registered',
#    'accept_rate': 70,
#    'profile_image': 'https://www.gravatar.com/avatar/65e361318ee533712efd7929d6e9977c?s=128&d=identicon&r=PG',
#    'display_name': 'Thomas',
#    'link': 'https://stackoverflow.com/users/2210667/thomas'},
#   'is_answered': False,
#   'view_count': 8,
#   'answer_count': 1,
#   'score': 0,
#   'last_activity_date': 1633126756,
#   'creation_date': 1633124742,
#   'last_edit_date': 1633126691,
#   'question_id': 69412251,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/69412251/why-would-a-replica-not-be-listed-as-a-kafka-broker',
#   'title': 'Why would a replica not be listed as a Kafka broker?'},
#  {'tags': ['omnet++', 'inet', 'passive-mode'],
#   'owner': {'account_id': 22685356,
#    'reputation': 1,
#    'user_id': 16855084,
#    'user_type': 'registered',
#    'profile_image': 'https://lh3.googleusercontent.com/a/AATXAJyLhbFyoWb0scje5zHak6kL6ZuyxDLB4Q4ZBCLV=k-s128',
#    'display_name': 'Safar Asaad',
#    'link': 'https://stackoverflow.com/users/16855084/safar-asaad'},
#   'is_answered': False,
#   'view_count': 3,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1633126754,
#   'creation_date': 1633126754,
#   'question_id': 69412468,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/69412468/how-to-make-a-wifi-node-to-be-in-passive-monitoring-mode',
#   'title': 'How to make a WiFi node to be in passive monitoring mode?'},
#  {'tags': ['java', 'windows', 'batch-file', 'cmd', 'utf'],
#   'owner': {'account_id': 21934133,
#    'reputation': 1,
#    'user_id': 16215672,
#    'user_type': 'registered',
#    'profile_image': 'https://lh3.googleusercontent.com/a-/AOh14GgdUaaxXjsrwZ2qgWZ52rbYK-WD4sCP4wZ-jVkpxQ=k-s128',
#    'display_name': 'Andr&#233;s Kertesz',
#    'link': 'https://stackoverflow.com/users/16215672/andr%c3%a9s-kertesz'},
#   'is_answered': False,
#   'view_count': 3,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1633126740,
#   'creation_date': 1633126740,
#   'question_id': 69412467,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/69412467/contents-within-a-bat-file-not-running-properly-when-running-said-bat-file',
#   'title': 'Contents within a .bat file not running properly when running said .bat file'},
#  {'tags': ['java', 'unit-testing', 'junit', 'mockito'],
#   'owner': {'account_id': 4260320,
#    'reputation': 313,
#    'user_id': 3484844,
#    'user_type': 'registered',
#    'accept_rate': 36,
#    'profile_image': 'https://www.gravatar.com/avatar/878e88a6d9188e4c17d30d8f5855595d?s=128&d=identicon&r=PG&f=1',
#    'display_name': 'Yellowjacket',
#    'link': 'https://stackoverflow.com/users/3484844/yellowjacket'},
#   'is_answered': False,
#   'view_count': 16,
#   'answer_count': 1,
#   'score': 0,
#   'last_activity_date': 1633126736,
#   'creation_date': 1633112411,
#   'question_id': 69410418,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/69410418/mock-final-method-in-superclass',
#   'title': 'Mock final method in superclass'},
#  {'tags': ['javascript'],
#   'owner': {'user_type': 'does_not_exist', 'display_name': 'user7319004'},
#   'is_answered': True,
#   'view_count': 45,
#   'accepted_answer_id': 56201221,
#   'answer_count': 4,
#   'score': 1,
#   'last_activity_date': 1633126734,
#   'creation_date': 1558198917,
#   'last_edit_date': 1558199221,
#   'question_id': 56201093,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/56201093/find-unique-properties-in-array-and-calculate-matching-items',
#   'title': 'Find unique properties in array and calculate matching items'},
#  {'tags': ['python'],
#   'owner': {'account_id': 11682107,
#    'reputation': 139,
#    'user_id': 13259521,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/564298cb174153ef0422727046150862?s=128&d=identicon&r=PG&f=1',
#    'display_name': 'GNZ',
#    'link': 'https://stackoverflow.com/users/13259521/gnz'},
#   'is_answered': False,
#   'view_count': 11,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1633126727,
#   'creation_date': 1633126727,
#   'question_id': 69412465,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/69412465/how-to-find-indexes-at-once-in-python-this-case',
#   'title': 'How to find indexes at once in Python this case?'},
#  {'tags': ['python', 'discord', 'discord.py', 'bots'],
#   'owner': {'account_id': 22810526,
#    'reputation': 1,
#    'user_id': 16961905,
#    'user_type': 'registered',
#    'profile_image': 'https://lh3.googleusercontent.com/a-/AOh14GjiW2ZEK0Y5H93woaUA_N6fliW0LFM_gzOE_OUetA=k-s128',
#    'display_name': 'Secretcode',
#    'link': 'https://stackoverflow.com/users/16961905/secretcode'},
#   'is_answered': False,
#   'view_count': 22,
#   'answer_count': 1,
#   'score': 0,
#   'last_activity_date': 1633126725,
#   'creation_date': 1633120612,
#   'question_id': 69411740,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/69411740/discord-python-kick-function-not-working-after-a-certain-time',
#   'title': 'Discord Python Kick Function not working after a certain time'}]

# %%
# Number of elements in a List
print("Number of elements in the 'items' list is", len(response_json['items']))
# Out:
# Number of elements in the 'items' list is 30

# %% [markdown]
# ### 4. Paging

# %%
# Loop through pages in API

# Define page, pagesize and fromdate parameters for fetching pages of results from the API (according to StackExchange documentation)
page = 1
pagesize = 100
fromdate = 1633046400 # 01.10.2021

has_more = True

# Create empty List
total_results = []

while has_more:   
    # Define the url with page, pagesize and fromdate parameters
    url = f"https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page={page}&pagesize={pagesize}&fromdate={fromdate}"
    print("Requesting:", url)
    
    # Response object returned from the API
    response = requests.get(url)
    
    # JSON response of the JSON object of the result
    response_data = response.json()
    
    # Check if data in 'items' is present
    if len(response_data['items']) == 0:
        # If not, exit the loop
        break
    # If yes, then add the specified list elements (or any iterable) to the end of the current list in order to collect all API results into a List
    total_results.extend(response_data['items'])
    
    # Increaae the page number by 1
    page += 1
    
    # Halt the code execution (timeout for 3 seconds added to prevent rate-limiting)
    time.sleep(3)
# Out:
# Requesting: https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page=1&pagesize=100&fromdate=1633046400
# Requesting: https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page=2&pagesize=100&fromdate=1633046400
# Requesting: https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page=3&pagesize=100&fromdate=1633046400
# Requesting: https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page=4&pagesize=100&fromdate=1633046400
# Requesting: https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page=5&pagesize=100&fromdate=1633046400
# Requesting: https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page=6&pagesize=100&fromdate=1633046400
# Requesting: https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page=7&pagesize=100&fromdate=1633046400
# Requesting: https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page=8&pagesize=100&fromdate=1633046400
# Requesting: https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page=9&pagesize=100&fromdate=1633046400
# Requesting: https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page=10&pagesize=100&fromdate=1633046400
# Requesting: https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page=11&pagesize=100&fromdate=1633046400
# Requesting: https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page=12&pagesize=100&fromdate=1633046400
# Requesting: https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page=13&pagesize=100&fromdate=1633046400
# Requesting: https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page=14&pagesize=100&fromdate=1633046400
# Requesting: https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page=15&pagesize=100&fromdate=1633046400
# Requesting: https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page=16&pagesize=100&fromdate=1633046400
# Requesting: https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page=17&pagesize=100&fromdate=1633046400
# Requesting: https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page=18&pagesize=100&fromdate=1633046400
# Requesting: https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page=19&pagesize=100&fromdate=1633046400
# Requesting: https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page=20&pagesize=100&fromdate=1633046400
# Requesting: https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page=21&pagesize=100&fromdate=1633046400
# Requesting: https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page=22&pagesize=100&fromdate=1633046400
# Requesting: https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page=23&pagesize=100&fromdate=1633046400
# Requesting: https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page=24&pagesize=100&fromdate=1633046400
# Requesting: https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page=25&pagesize=100&fromdate=1633046400
# Requesting: https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page=26&pagesize=100&fromdate=1633046400
# Requesting: https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page=27&pagesize=100&fromdate=1633046400
# Requesting: https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page=28&pagesize=100&fromdate=1633046400
# Requesting: https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page=29&pagesize=100&fromdate=1633046400
# Requesting: https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page=30&pagesize=100&fromdate=1633046400
# Requesting: https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page=31&pagesize=100&fromdate=1633046400
# Requesting: https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page=32&pagesize=100&fromdate=1633046400
# Requesting: https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page=33&pagesize=100&fromdate=1633046400
# Requesting: https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page=34&pagesize=100&fromdate=1633046400
# Requesting: https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page=35&pagesize=100&fromdate=1633046400
# Requesting: https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page=36&pagesize=100&fromdate=1633046400
# Requesting: https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page=37&pagesize=100&fromdate=1633046400
# Requesting: https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page=38&pagesize=100&fromdate=1633046400
# Requesting: https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page=39&pagesize=100&fromdate=1633046400
# Requesting: https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page=40&pagesize=100&fromdate=1633046400
# Requesting: https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page=41&pagesize=100&fromdate=1633046400
# Requesting: https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page=42&pagesize=100&fromdate=1633046400
# Requesting: https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page=43&pagesize=100&fromdate=1633046400
# Requesting: https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page=44&pagesize=100&fromdate=1633046400
# Requesting: https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page=45&pagesize=100&fromdate=1633046400
# Requesting: https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page=46&pagesize=100&fromdate=1633046400
# Requesting: https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page=47&pagesize=100&fromdate=1633046400
# Requesting: https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page=48&pagesize=100&fromdate=1633046400
# Requesting: https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page=49&pagesize=100&fromdate=1633046400
# Requesting: https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page=50&pagesize=100&fromdate=1633046400
# Requesting: https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page=51&pagesize=100&fromdate=1633046400
# Requesting: https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page=52&pagesize=100&fromdate=1633046400
# Requesting: https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page=53&pagesize=100&fromdate=1633046400
# Requesting: https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page=54&pagesize=100&fromdate=1633046400
# Requesting: https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page=55&pagesize=100&fromdate=1633046400
# Requesting: https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page=56&pagesize=100&fromdate=1633046400
# Requesting: https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page=57&pagesize=100&fromdate=1633046400
# Requesting: https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page=58&pagesize=100&fromdate=1633046400
# Requesting: https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page=59&pagesize=100&fromdate=1633046400
# Requesting: https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page=60&pagesize=100&fromdate=1633046400
# Requesting: https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page=61&pagesize=100&fromdate=1633046400

# %%
# Number of elements in a List
print(len(total_results))
# Out:
# 5974

# %% [markdown]
# ### 5. Add Data into Pandas DataFrame

# %% [markdown]
# #### using .DataFrame()

# %%
# Add Data into Pandas DataFrame
df = pd.DataFrame(total_results)

# %%
# Print out the Pandas DataFrame
print(df)
# Out:
#                                                    tags  \
# 0                                      [reactjs, redux]
# 1                     [javascript, reactjs, api, fetch]
# 2                                                 [css]
# 3            [python, sql, python-3.x, sqlite, tkinter]
# 4                         [postgresql, database-design]
# ...                                                 ...
# 5969                         [r, r-markdown, flextable]
# 5970                     [python, mysql, excel, pandas]
# 5971  [android, flutter, dart, push-notification, fi...
# 5972                           [java, logic, math.sqrt]
# 5973                                       [java, json]
#
#                                                   owner  is_answered  \
# 0     {'account_id': 21317036, 'reputation': 29, 'us...        False
# 1     {'account_id': 20580108, 'reputation': 53, 'us...         True
# 2     {'account_id': 5157897, 'reputation': 217, 'us...        False
# 3     {'account_id': 22753997, 'reputation': 25, 'us...        False
# 4     {'account_id': 6515552, 'reputation': 1, 'user...        False
# ...                                                 ...          ...
# 5969  {'account_id': 18059282, 'reputation': 135, 'u...        False
# 5970  {'account_id': 16609211, 'reputation': 43, 'us...        False
# 5971  {'account_id': 20905383, 'reputation': 1, 'use...        False
# 5972  {'account_id': 22458868, 'reputation': 5, 'use...        False
# 5973  {'account_id': 19782045, 'reputation': 347, 'u...        False
#
#       view_count  answer_count  score  last_activity_date  creation_date  \
# 0             12             0      0          1633126882     1633126243
# 1             41             4      1          1633126878     1633119975
# 2              8             1      0          1633126877     1633126410
# 3             17             0      0          1633126873     1633123896
# 4              2             0      0          1633126872     1633126872
# ...          ...           ...    ...                 ...            ...
# 5969          13             0      0          1633046660     1633046660
# 5970           9             0      0          1633046646     1633046646
# 5971          11             0      0          1633046546     1633046546
# 5972          27             0      0          1633046495     1633046495
# 5973          24             0      0          1633046432     1633046432
#
#       last_edit_date  question_id content_license  \
# 0       1.633127e+09     69412410    CC BY-SA 4.0
# 1                NaN     69411652    CC BY-SA 4.0
# 2                NaN     69412432    CC BY-SA 4.0
# 3       1.633127e+09     69412157    CC BY-SA 4.0
# 4                NaN     69412480    CC BY-SA 4.0
# ...              ...          ...             ...
# 5969             NaN     69399943    CC BY-SA 4.0
# 5970             NaN     69399939    CC BY-SA 4.0
# 5971             NaN     69399931    CC BY-SA 4.0
# 5972             NaN     69399928    CC BY-SA 4.0
# 5973             NaN     69399926    CC BY-SA 4.0
#
#                                                    link  \
# 0     https://stackoverflow.com/questions/69412410/w...
# 1     https://stackoverflow.com/questions/69411652/h...
# 2     https://stackoverflow.com/questions/69412432/w...
# 3     https://stackoverflow.com/questions/69412157/p...
# 4     https://stackoverflow.com/questions/69412480/i...
# ...                                                 ...
# 5969  https://stackoverflow.com/questions/69399943/i...
# 5970  https://stackoverflow.com/questions/69399939/h...
# 5971  https://stackoverflow.com/questions/69399931/t...
# 5972  https://stackoverflow.com/questions/69399928/t...
# 5973  https://stackoverflow.com/questions/69399926/d...
#
#                                                   title  accepted_answer_id  \
# 0     Why am I receiving &#39;Invalid hook call&#39;...                 NaN
# 1     How to use two map function with two fetching url          69412270.0
# 2     Why isn&#39;t the background color in my nav r...                 NaN
# 3     Problem saving field in database: insert 2 fie...                 NaN
# 4     Is it possible to build a table of device inte...                 NaN
# ...                                                 ...                 ...
# 5969  Is there a way to automatically position and f...                 NaN
# 5970  How to delete duplicate rows from table in SQL...                 NaN
# 5971  Trying to run periodic code in background of f...                 NaN
# 5972                              The logic sqrt method                 NaN
# 5973  Deserializing a Json with lists of objects usi...                 NaN
#
#       closed_date closed_reason migrated_to  locked_date migrated_from
# 0             NaN           NaN         NaN          NaN           NaN
# 1             NaN           NaN         NaN          NaN           NaN
# 2             NaN           NaN         NaN          NaN           NaN
# 3             NaN           NaN         NaN          NaN           NaN
# 4             NaN           NaN         NaN          NaN           NaN
# ...           ...           ...         ...          ...           ...
# 5969          NaN           NaN         NaN          NaN           NaN
# 5970          NaN           NaN         NaN          NaN           NaN
# 5971          NaN           NaN         NaN          NaN           NaN
# 5972          NaN           NaN         NaN          NaN           NaN
# 5973          NaN           NaN         NaN          NaN           NaN
#
# [5974 rows x 19 columns]

# %%
# Display the few top rows of Pandas DataFrame
df.head()
# Out:
#                                          tags  \
# 0                            [reactjs, redux]
# 1           [javascript, reactjs, api, fetch]
# 2                                       [css]
# 3  [python, sql, python-3.x, sqlite, tkinter]
# 4               [postgresql, database-design]
#
#                                                owner  is_answered  view_count  \
# 0  {'account_id': 21317036, 'reputation': 29, 'us...        False          12
# 1  {'account_id': 20580108, 'reputation': 53, 'us...         True          41
# 2  {'account_id': 5157897, 'reputation': 217, 'us...        False           8
# 3  {'account_id': 22753997, 'reputation': 25, 'us...        False          17
# 4  {'account_id': 6515552, 'reputation': 1, 'user...        False           2
#
#    answer_count  score  last_activity_date  creation_date  last_edit_date  \
# 0             0      0          1633126882     1633126243    1.633127e+09
# 1             4      1          1633126878     1633119975             NaN
# 2             1      0          1633126877     1633126410             NaN
# 3             0      0          1633126873     1633123896    1.633127e+09
# 4             0      0          1633126872     1633126872             NaN
#
#    question_id content_license  \
# 0     69412410    CC BY-SA 4.0
# 1     69411652    CC BY-SA 4.0
# 2     69412432    CC BY-SA 4.0
# 3     69412157    CC BY-SA 4.0
# 4     69412480    CC BY-SA 4.0
#
#                                                 link  \
# 0  https://stackoverflow.com/questions/69412410/w...
# 1  https://stackoverflow.com/questions/69411652/h...
# 2  https://stackoverflow.com/questions/69412432/w...
# 3  https://stackoverflow.com/questions/69412157/p...
# 4  https://stackoverflow.com/questions/69412480/i...
#
#                                                title  accepted_answer_id  \
# 0  Why am I receiving &#39;Invalid hook call&#39;...                 NaN
# 1  How to use two map function with two fetching url          69412270.0
# 2  Why isn&#39;t the background color in my nav r...                 NaN
# 3  Problem saving field in database: insert 2 fie...                 NaN
# 4  Is it possible to build a table of device inte...                 NaN
#
#    closed_date closed_reason migrated_to  locked_date migrated_from
# 0          NaN           NaN         NaN          NaN           NaN
# 1          NaN           NaN         NaN          NaN           NaN
# 2          NaN           NaN         NaN          NaN           NaN
# 3          NaN           NaN         NaN          NaN           NaN
# 4          NaN           NaN         NaN          NaN           NaN

# %%
# Display the few last rows of Pandas DataFrame
df.tail()
# Out:
#                                                    tags  \
# 5969                         [r, r-markdown, flextable]
# 5970                     [python, mysql, excel, pandas]
# 5971  [android, flutter, dart, push-notification, fi...
# 5972                           [java, logic, math.sqrt]
# 5973                                       [java, json]
#
#                                                   owner  is_answered  \
# 5969  {'account_id': 18059282, 'reputation': 135, 'u...        False
# 5970  {'account_id': 16609211, 'reputation': 43, 'us...        False
# 5971  {'account_id': 20905383, 'reputation': 1, 'use...        False
# 5972  {'account_id': 22458868, 'reputation': 5, 'use...        False
# 5973  {'account_id': 19782045, 'reputation': 347, 'u...        False
#
#       view_count  answer_count  score  last_activity_date  creation_date  \
# 5969          13             0      0          1633046660     1633046660
# 5970           9             0      0          1633046646     1633046646
# 5971          11             0      0          1633046546     1633046546
# 5972          27             0      0          1633046495     1633046495
# 5973          24             0      0          1633046432     1633046432
#
#       last_edit_date  question_id content_license  \
# 5969             NaN     69399943    CC BY-SA 4.0
# 5970             NaN     69399939    CC BY-SA 4.0
# 5971             NaN     69399931    CC BY-SA 4.0
# 5972             NaN     69399928    CC BY-SA 4.0
# 5973             NaN     69399926    CC BY-SA 4.0
#
#                                                    link  \
# 5969  https://stackoverflow.com/questions/69399943/i...
# 5970  https://stackoverflow.com/questions/69399939/h...
# 5971  https://stackoverflow.com/questions/69399931/t...
# 5972  https://stackoverflow.com/questions/69399928/t...
# 5973  https://stackoverflow.com/questions/69399926/d...
#
#                                                   title  accepted_answer_id  \
# 5969  Is there a way to automatically position and f...                 NaN
# 5970  How to delete duplicate rows from table in SQL...                 NaN
# 5971  Trying to run periodic code in background of f...                 NaN
# 5972                              The logic sqrt method                 NaN
# 5973  Deserializing a Json with lists of objects usi...                 NaN
#
#       closed_date closed_reason migrated_to  locked_date migrated_from
# 5969          NaN           NaN         NaN          NaN           NaN
# 5970          NaN           NaN         NaN          NaN           NaN
# 5971          NaN           NaN         NaN          NaN           NaN
# 5972          NaN           NaN         NaN          NaN           NaN
# 5973          NaN           NaN         NaN          NaN           NaN

# %% [markdown]
# ### 6. Pandas DataFrame to .csv file

# %%
# Write Pandas DataFrame to .csv file
df.to_csv('C:/Users/Administrator/Desktop/Data Engineer/stack_exchange_questions.csv', index = False)
