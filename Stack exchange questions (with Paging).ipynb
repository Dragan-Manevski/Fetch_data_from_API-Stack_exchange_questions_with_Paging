# %% [markdown]
# ## Stack exchange questions (with Paging)

# %% [markdown]
# ### 1. Import the Libraries

# %%
# Import Pandas, Requests, JSON and Time library
import pandas as pd
import requests
import json
import time

# %% [markdown]
# ### 2. Generate URL request, access its status code attribute and access data

# %%
# Response object returned from the API
response_API = requests.get("https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow")

# %%
# Print out the status code value
print(response_API.status_code)
# Out:
# 200

# %% [markdown]
# ### 3. Convert JSON string into Python object (Dictionary)

# %%
# JSON response of the JSON object of the result
response_json = response_API.json()

# Show the JSON response
response_json
# Out:
# {'items': [{'tags': ['node.js', 'typescript', 'testing', 'jestjs'],
#    'owner': {'account_id': 19362206,
#     'reputation': 21,
#     'user_id': 14157249,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/8cb46049f5947f1a51193529697693ba?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Steve',
#     'link': 'https://stackoverflow.com/users/14157249/steve'},
#    'is_answered': False,
#    'view_count': 2,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1633155614,
#    'creation_date': 1633155614,
#    'question_id': 69414512,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69414512/how-can-i-handle-jest-has-detected-the-following-open-handles-potentially-keepin',
#    'title': 'How can i handle jest has detected the following open handles potentially keeping Jest from exiting when using node-ftech'},
#   {'tags': ['node.js', 'reactjs', 'npm', 'publish', 'lint'],
#    'owner': {'account_id': 16270137,
#     'reputation': 1167,
#     'user_id': 11749004,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/f62bb8f1336b7417925747fcd790f5c0?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Kid',
#     'link': 'https://stackoverflow.com/users/11749004/kid'},
#    'is_answered': False,
#    'view_count': 23,
#    'answer_count': 0,
#    'score': 1,
#    'last_activity_date': 1633155614,
#    'creation_date': 1633121801,
#    'last_edit_date': 1633155614,
#    'question_id': 69411911,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69411911/why-did-i-get-the-no-unused-expressions-error-on-npm-start-here-in-my-case',
#    'title': 'Why did I get the no-unused-expressions error on &quot;npm start&quot; here in my case'},
#   {'tags': ['java', 'mapping', 'mapstruct'],
#    'owner': {'account_id': 15292689,
#     'reputation': 1,
#     'user_id': 11033756,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/-_jcx-Lxzj50/AAAAAAAAAAI/AAAAAAAAIuU/Vr2yxF4SauY/photo.jpg?sz=128',
#     'display_name': 'Silaghi Alexandru-Mihail',
#     'link': 'https://stackoverflow.com/users/11033756/silaghi-alexandru-mihail'},
#    'is_answered': False,
#    'view_count': 14,
#    'answer_count': 1,
#    'score': 0,
#    'last_activity_date': 1633155605,
#    'creation_date': 1632480629,
#    'question_id': 69313771,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69313771/mapstruct-package-private-attributes',
#    'title': 'Mapstruct package private attributes'},
#   {'tags': ['javascript', 'node.js', 'cheerio'],
#    'owner': {'account_id': 13391178,
#     'reputation': 2691,
#     'user_id': 9663497,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/a2146a2188db75aa6c8d552e7804ea30?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Vincenzo',
#     'link': 'https://stackoverflow.com/users/9663497/vincenzo'},
#    'is_answered': False,
#    'view_count': 11,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1633155582,
#    'creation_date': 1633152100,
#    'last_edit_date': 1633155582,
#    'question_id': 69414213,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69414213/typeerror-dom-getelementsbytagname-is-not-a-function-node-js',
#    'title': 'TypeError: dom.getElementsByTagName is not a function Node.js'},
#   {'tags': ['ios', 'xcode', 'icons', 'tabview', 'sf-symbols'],
#    'owner': {'account_id': 11987709,
#     'reputation': 373,
#     'user_id': 8771798,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/d8c740e16aca1e8a49b063e3762ca4ef?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Flincorp',
#     'link': 'https://stackoverflow.com/users/8771798/flincorp'},
#    'is_answered': False,
#    'view_count': 43,
#    'answer_count': 1,
#    'score': 1,
#    'last_activity_date': 1633155566,
#    'creation_date': 1632507584,
#    'question_id': 69319575,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69319575/how-to-change-filled-icon-to-not-filled-on-tabview-tabitem-in-ios-15-xcode-13',
#    'title': 'How to change filled icon to not filled on TabView tabItem in iOS 15 Xcode 13?'},
#   {'tags': ['python'],
#    'owner': {'account_id': 22248294,
#     'reputation': 1,
#     'user_id': 16481640,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/73ebd3a4485cd80d9ce0ebc8a41aba10?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'AdityaCodes',
#     'link': 'https://stackoverflow.com/users/16481640/adityacodes'},
#    'is_answered': False,
#    'view_count': 4,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1633155563,
#    'creation_date': 1633155563,
#    'question_id': 69414509,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69414509/having-a-problem-in-python-showing-error-can-only-concatenate-str-not-bool',
#    'title': 'Having a problem in python: Showing error can only concatenate str (not &quot;bool&quot;) to str'},
#   {'tags': ['python', 'pyqt5', 'icons', 'qfiledialog'],
#    'owner': {'account_id': 18802257,
#     'reputation': 1,
#     'user_id': 13712328,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a-/AOh14GhIfQwyZE_YhsMhw-AHgpvYPB5XCbd6gLofWv3d=k-s128',
#     'display_name': 'sana sm',
#     'link': 'https://stackoverflow.com/users/13712328/sana-sm'},
#    'is_answered': False,
#    'view_count': 21,
#    'closed_date': 1632759677,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1633155562,
#    'creation_date': 1632736379,
#    'last_edit_date': 1633155562,
#    'question_id': 69344641,
#    'link': 'https://stackoverflow.com/questions/69344641/set-icon-when-saving-file-in-pyqt5',
#    'closed_reason': 'Needs details or clarity',
#    'title': 'set icon when saving file in pyqt5'},
#   {'tags': ['java'],
#    'owner': {'account_id': 5672211,
#     'reputation': 4058,
#     'user_id': 4969916,
#     'user_type': 'registered',
#     'accept_rate': 35,
#     'profile_image': 'https://lh6.googleusercontent.com/-QNfz4LV_I8A/AAAAAAAAAAI/AAAAAAAAAD0/lvTyKboHs6s/photo.jpg?sz=128',
#     'display_name': 'Shiladittya Chakraborty',
#     'link': 'https://stackoverflow.com/users/4969916/shiladittya-chakraborty'},
#    'is_answered': False,
#    'view_count': 35,
#    'answer_count': 2,
#    'score': 0,
#    'last_activity_date': 1633155554,
#    'creation_date': 1633151930,
#    'question_id': 69414200,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69414200/remove-data-from-one-list-with-another-list-data-function-not-working-properly',
#    'title': 'remove data from one list with another list data function not working properly'},
#   {'tags': ['java', 'eclipse', 'while-loop', 'syntax', 'integer'],
#    'owner': {'account_id': 22920572,
#     'reputation': 1,
#     'user_id': 17056464,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/1afc1eba6030118e32ddab86e942cb52?s=128&d=identicon&r=PG',
#     'display_name': 'Sridevi',
#     'link': 'https://stackoverflow.com/users/17056464/sridevi'},
#    'is_answered': False,
#    'view_count': 4,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1633155545,
#    'creation_date': 1633155545,
#    'question_id': 69414508,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69414508/why-it-is-showing-syntax-error-like-syntax-error-on-token-class-invalid-expr',
#    'title': 'why it is showing syntax error like &quot;Syntax error on token &quot;class&quot;, invalid Expression&quot;'},
#   {'tags': ['python', 'macos', 'jupyter-notebook', 'plaidml'],
#    'owner': {'account_id': 17775293,
#     'reputation': 9,
#     'user_id': 12907797,
#     'user_type': 'registered',
#     'profile_image': 'https://graph.facebook.com/3261884620492353/picture?type=large',
#     'display_name': 'I-Fan Lin',
#     'link': 'https://stackoverflow.com/users/12907797/i-fan-lin'},
#    'is_answered': False,
#    'view_count': 50,
#    'answer_count': 1,
#    'score': 0,
#    'last_activity_date': 1633155545,
#    'creation_date': 1620146760,
#    'question_id': 67388836,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/67388836/i-used-plaidml-in-python-but-my-gpu-did-not-run-i-use-macbook-pro-16-2019',
#    'title': 'I used plaidml in python but my GPU did not run. ( I use Macbook Pro 16, 2019)'},
#   {'tags': ['javascript'],
#    'owner': {'account_id': 22833137,
#     'reputation': 9,
#     'user_id': 16981270,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a/AATXAJx71xZZwRa12RZjdISEUgtmQL45QuLR7Xa8pqpX=k-s128',
#     'display_name': 'Milton T',
#     'link': 'https://stackoverflow.com/users/16981270/milton-t'},
#    'is_answered': True,
#    'view_count': 70,
#    'accepted_answer_id': 69413811,
#    'answer_count': 5,
#    'score': -1,
#    'last_activity_date': 1633155541,
#    'creation_date': 1633141384,
#    'last_edit_date': 1633142440,
#    'question_id': 69413520,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69413520/automatically-remove-a-div-with-javascript',
#    'title': 'automatically remove a div with javascript'},
#   {'tags': ['python', 'sum'],
#    'owner': {'account_id': 22874295,
#     'reputation': 1,
#     'user_id': 17016873,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a/AATXAJwozMar6qxCh7KG-nWfVB0yTwzbCf_I1ylU70Bp=k-s128',
#     'display_name': 'sunday rose',
#     'link': 'https://stackoverflow.com/users/17016873/sunday-rose'},
#    'is_answered': False,
#    'view_count': 35,
#    'answer_count': 3,
#    'score': -1,
#    'last_activity_date': 1633155540,
#    'creation_date': 1633154344,
#    'last_edit_date': 1633154661,
#    'question_id': 69414399,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69414399/what-is-wrong-in-this-python-code-i-want-to-return-the-sum-of-digits-ex-123',
#    'title': 'What is wrong in this python code? I want to return the sum of digits, Ex. 123 == 1+2+3 = 6 using sum() function in python?'},
#   {'tags': ['excel', 'vba'],
#    'owner': {'account_id': 22919346,
#     'reputation': 1,
#     'user_id': 17055408,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/942f37c2b7e05f60a1980741688bc609?s=128&d=identicon&r=PG',
#     'display_name': 'berclaw',
#     'link': 'https://stackoverflow.com/users/17055408/berclaw'},
#    'is_answered': False,
#    'view_count': 18,
#    'answer_count': 1,
#    'score': 0,
#    'last_activity_date': 1633155535,
#    'creation_date': 1633144447,
#    'question_id': 69413690,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69413690/trying-to-loop-through-files-and-copy-an-array-of-sheets-using-vba-getting-erro',
#    'title': 'Trying to loop through files and copy an array of sheets using VBA, getting Error 424 Object Required'},
#   {'tags': ['matlab'],
#    'owner': {'account_id': 17753836,
#     'reputation': 79,
#     'user_id': 12893769,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/5b9e2feba94547f07ad99f697d6d4946?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'alirazi',
#     'link': 'https://stackoverflow.com/users/12893769/alirazi'},
#    'is_answered': False,
#    'view_count': 3,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1633155533,
#    'creation_date': 1633155533,
#    'question_id': 69414506,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69414506/merge-strings-and-table-to-one-text-file-using-fprintf-matlab',
#    'title': 'Merge strings and table to one text file using fprintf - Matlab'},
#   {'tags': ['c++', 'parameter-pack'],
#    'owner': {'account_id': 20404882,
#     'reputation': 1,
#     'user_id': 14969712,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/e7f20223ff6729361c60034dc31acb5b?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'GGeorge',
#     'link': 'https://stackoverflow.com/users/14969712/ggeorge'},
#    'is_answered': False,
#    'view_count': 24,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1633155528,
#    'creation_date': 1633149204,
#    'last_edit_date': 1633155528,
#    'question_id': 69413986,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69413986/paramater-pack-extraction',
#    'title': 'Paramater pack extraction'},
#   {'tags': ['c', 'gcc', 'compilation', 'compiler-optimization'],
#    'owner': {'account_id': 10734102,
#     'reputation': 388,
#     'user_id': 7899226,
#     'user_type': 'registered',
#     'profile_image': 'https://lh6.googleusercontent.com/-ler-_6Kql0U/AAAAAAAAAAI/AAAAAAAAACY/ZJfWk7xOZPE/photo.jpg?sz=128',
#     'display_name': '0xF4D3C0D3',
#     'link': 'https://stackoverflow.com/users/7899226/0xf4d3c0d3'},
#    'is_answered': True,
#    'view_count': 33,
#    'answer_count': 2,
#    'score': 1,
#    'last_activity_date': 1633155528,
#    'creation_date': 1633150595,
#    'question_id': 69414094,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69414094/gcc-optmizes-printf-to-puts-i-dont-want-that',
#    'title': 'gcc optmizes printf to puts. I don&#39;t want that'},
#   {'tags': ['vba', 'mailmerge'],
#    'owner': {'account_id': 15761061,
#     'reputation': 3,
#     'user_id': 11372761,
#     'user_type': 'registered',
#     'profile_image': 'https://lh4.googleusercontent.com/-x4PdSNOcXDk/AAAAAAAAAAI/AAAAAAAAKe4/SwuFKDe3Nlw/photo.jpg?sz=128',
#     'display_name': 'Shaf3067',
#     'link': 'https://stackoverflow.com/users/11372761/shaf3067'},
#    'is_answered': False,
#    'view_count': 2,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1633155524,
#    'creation_date': 1633155524,
#    'question_id': 69414504,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69414504/mail-merge-document-group-by-and-save-in-one-pdf-format-as-per-the-employee',
#    'title': 'Mail Merge Document ..! group by and Save in one PDF format as per the Employee Name Like SMS Thread'},
#   {'tags': ['google-analytics', 'google-analytics-api'],
#    'owner': {'account_id': 313122,
#     'reputation': 283,
#     'user_id': 627582,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/a2f1245315981918934bcf988d319ef4?s=128&d=identicon&r=PG',
#     'display_name': 'pedroaxl',
#     'link': 'https://stackoverflow.com/users/627582/pedroaxl'},
#    'is_answered': True,
#    'view_count': 4771,
#    'accepted_answer_id': 32232244,
#    'answer_count': 2,
#    'score': 7,
#    'last_activity_date': 1633155512,
#    'creation_date': 1440607298,
#    'question_id': 32232169,
#    'content_license': 'CC BY-SA 3.0',
#    'link': 'https://stackoverflow.com/questions/32232169/daily-weekly-monthly-active-users-on-google-analytics-api',
#    'title': 'Daily/Weekly/Monthly Active Users on Google Analytics API'},
#   {'tags': ['visual-studio-code'],
#    'owner': {'account_id': 22920557,
#     'reputation': 1,
#     'user_id': 17056449,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a-/AOh14GiRqRvRr7wn75mqckXkjnMllSsqanh4cKcBfroleg=k-s128',
#     'display_name': 'Md Noorul Haque',
#     'link': 'https://stackoverflow.com/users/17056449/md-noorul-haque'},
#    'is_answered': False,
#    'view_count': 4,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1633155510,
#    'creation_date': 1633155510,
#    'question_id': 69414502,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69414502/couldnt-start-client-azure-resource-manager-template-in-vs-code',
#    'title': 'Couldn&#39;t start client Azure Resource Manager Template in VS Code'},
#   {'tags': ['r', 'regex', 'tidyr'],
#    'owner': {'account_id': 22308983,
#     'reputation': 13,
#     'user_id': 16533236,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/b3f9489b7d31f9e942d6c25fdc19a104?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Hi_Viz',
#     'link': 'https://stackoverflow.com/users/16533236/hi-viz'},
#    'is_answered': False,
#    'view_count': 11,
#    'answer_count': 1,
#    'score': 0,
#    'last_activity_date': 1633155506,
#    'creation_date': 1633154528,
#    'question_id': 69414414,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69414414/pivot-longer-with-regex-for-two-digit-numbers-in-names-pattern',
#    'title': 'Pivot_longer with regex for two-digit numbers in names_pattern'},
#   {'tags': ['java', 'netbeans', 'jframe', 'netbeans-12'],
#    'owner': {'account_id': 22880973,
#     'reputation': 3,
#     'user_id': 17022570,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/dbba86cb130e9069b649377474b56f75?s=128&d=identicon&r=PG',
#     'display_name': 'JFan',
#     'link': 'https://stackoverflow.com/users/17022570/jfan'},
#    'is_answered': False,
#    'view_count': 5,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1633155493,
#    'creation_date': 1633155493,
#    'question_id': 69414500,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69414500/netbeans-gui-builder-from-existing-file',
#    'title': 'NetBeans GUI Builder from existing file'},
#   {'tags': ['django-models', 'django-views', 'django-templates'],
#    'owner': {'account_id': 22845637,
#     'reputation': 3,
#     'user_id': 16992014,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a-/AOh14GjlAAWimvUfTbr-Uj82uUq9PudgjVHvz1IHRrJAAQ=k-s128',
#     'display_name': 'Ashok shah',
#     'link': 'https://stackoverflow.com/users/16992014/ashok-shah'},
#    'is_answered': False,
#    'view_count': 7,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1633155490,
#    'creation_date': 1633154502,
#    'last_edit_date': 1633155490,
#    'question_id': 69414411,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69414411/hi-i-want-to-display-dynamic-data-first-row-is-in-6-columns-other-is-col-3-col',
#    'title': 'Hi, I want to display dynamic data, First row is in 6 columns other is col-3 col-3'},
#   {'tags': ['python', 'algorithm', 'encryption', 'hash'],
#    'owner': {'account_id': 8921343,
#     'reputation': 2397,
#     'user_id': 8124392,
#     'user_type': 'registered',
#     'accept_rate': 94,
#     'profile_image': 'https://www.gravatar.com/avatar/29ccdaed954c2c2d9da35fcefcadcb95?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'oo92',
#     'link': 'https://stackoverflow.com/users/8124392/oo92'},
#    'is_answered': False,
#    'view_count': 7,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1633155484,
#    'creation_date': 1633155484,
#    'question_id': 69414499,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69414499/find-a-hash-encryption-input-from-an-output',
#    'title': 'Find a hash encryption input from an output'},
#   {'tags': ['for-loop'],
#    'owner': {'account_id': 22920424,
#     'reputation': 1,
#     'user_id': 17056338,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a/AATXAJwXCmCRNfZ-Yb4NGsmY27EaSIsAA5Ip7kx-ccquKg=k-s128',
#     'display_name': 'NurlanK',
#     'link': 'https://stackoverflow.com/users/17056338/nurlank'},
#    'is_answered': False,
#    'view_count': 10,
#    'answer_count': 1,
#    'score': 0,
#    'last_activity_date': 1633155482,
#    'creation_date': 1633153532,
#    'last_edit_date': 1633153841,
#    'question_id': 69414329,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69414329/transcribing-for-loop-in-one-line-to-staircase-for-loop',
#    'title': 'Transcribing for-loop in one line to staircase for-loop'},
#   {'tags': ['sql', 'null', 'inner-join'],
#    'owner': {'account_id': 17767169,
#     'reputation': 1,
#     'user_id': 12901748,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a-/AAuE7mCVNixbfmAzC1qbts04qGJ0kIIhjYFqlhHy7dC3=k-s128',
#     'display_name': 'Shubham Londhe',
#     'link': 'https://stackoverflow.com/users/12901748/shubham-londhe'},
#    'is_answered': False,
#    'view_count': 10,
#    'answer_count': 1,
#    'score': -2,
#    'last_activity_date': 1633155472,
#    'creation_date': 1633154178,
#    'question_id': 69414382,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69414382/how-to-write-sql-query-to-join-2-tables-with-common-column-and-fill-empty-row-by',
#    'title': 'how to write sql query to join 2 tables with common column and fill empty row by NULL keyword'},
#   {'tags': ['html', 'css'],
#    'owner': {'account_id': 20996859,
#     'reputation': 1,
#     'user_id': 15428493,
#     'user_type': 'registered',
#     'profile_image': 'https://graph.facebook.com/3154190068141214/picture?type=large',
#     'display_name': 'MatchaLattee',
#     'link': 'https://stackoverflow.com/users/15428493/matchalattee'},
#    'is_answered': False,
#    'view_count': 32,
#    'answer_count': 1,
#    'score': 0,
#    'last_activity_date': 1633155469,
#    'creation_date': 1633145113,
#    'last_edit_date': 1633155052,
#    'question_id': 69413741,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69413741/how-do-i-fix-this-overflow-problem-when-using-hover-function',
#    'title': 'How do I fix this overflow problem when using hover function'},
#   {'tags': ['php'],
#    'owner': {'account_id': 22920592,
#     'reputation': 1,
#     'user_id': 17056483,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a-/AOh14GiZIEona0Sf9ocpU4PT3x_nzsi5_chXvEOEQFAoIA=k-s128',
#     'display_name': 'sasitharan sasi',
#     'link': 'https://stackoverflow.com/users/17056483/sasitharan-sasi'},
#    'is_answered': False,
#    'view_count': 7,
#    'answer_count': 0,
#    'score': -1,
#    'last_activity_date': 1633155460,
#    'creation_date': 1633155460,
#    'question_id': 69414495,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69414495/how-to-add-an-blog-cms-in-an-existing-user-management-php-website',
#    'title': 'How to add an blog cms in an existing user management php website?'},
#   {'tags': ['javascript', 'reactjs', 'async-await', 'onclick', 'return'],
#    'owner': {'account_id': 18842021,
#     'reputation': 206,
#     'user_id': 13743242,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/Vui01.jpg?s=128&g=1',
#     'display_name': 'Jesse G',
#     'link': 'https://stackoverflow.com/users/13743242/jesse-g'},
#    'is_answered': False,
#    'view_count': 6,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1633155458,
#    'creation_date': 1633155458,
#    'question_id': 69414494,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69414494/how-can-i-use-an-async-function-to-await-for-an-onclick-event-choice-between',
#    'title': 'How can I use an async function to await for an onClick() event (Choice between 2 Buttons in a Modal)'},
#   {'tags': ['shell', 'find', 'sh', 'posix', 'nice'],
#    'owner': {'account_id': 4620617,
#     'reputation': 1798,
#     'user_id': 3745821,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/DYzuR.jpg?s=128&g=1',
#     'display_name': 'Michael Back',
#     'link': 'https://stackoverflow.com/users/3745821/michael-back'},
#    'is_answered': False,
#    'view_count': 13,
#    'closed_date': 1633152227,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1633155458,
#    'creation_date': 1633150495,
#    'last_edit_date': 1633155458,
#    'question_id': 69414084,
#    'link': 'https://stackoverflow.com/questions/69414084/how-do-i-stop-find-from-outputting-error-in-posix-shell-driven-by-cron',
#    'closed_reason': 'Not suitable for this site',
#    'title': 'How do I stop &quot;find&quot; from outputting error in POSIX Shell driven by CRON?'},
#   {'tags': ['user-interface', 'testing', 'automation', 'automated-tests'],
#    'owner': {'account_id': 186,
#     'reputation': 27904,
#     'user_id': 230,
#     'user_type': 'registered',
#     'accept_rate': 54,
#     'profile_image': 'https://www.gravatar.com/avatar/decf93f3a084227668147039af95c302?s=128&d=identicon&r=PG',
#     'display_name': 'Dan',
#     'link': 'https://stackoverflow.com/users/230/dan'},
#    'is_answered': True,
#    'view_count': 22057,
#    'closed_date': 1365243646,
#    'accepted_answer_id': 805934,
#    'answer_count': 17,
#    'score': 33,
#    'last_activity_date': 1633155444,
#    'creation_date': 1241079798,
#    'last_edit_date': 1633155444,
#    'question_id': 805910,
#    'link': 'https://stackoverflow.com/questions/805910/what-is-the-best-automated-website-ui-testing-framework',
#    'closed_reason': 'not constructive',
#    'title': 'What is the best automated website UI testing framework'}],
#  'has_more': True,
#  'quota_max': 300,
#  'quota_remaining': 28}

# %%
# Show the Keys of the Dictionary as a List
response_json.keys()
# Out:
# dict_keys(['items', 'has_more', 'quota_max', 'quota_remaining'])

# %%
# Show the Value of the Key ('items') of the Dictionary as a List
response_json['items']
# Out:
# [{'tags': ['node.js', 'typescript', 'testing', 'jestjs'],
#   'owner': {'account_id': 19362206,
#    'reputation': 21,
#    'user_id': 14157249,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/8cb46049f5947f1a51193529697693ba?s=128&d=identicon&r=PG&f=1',
#    'display_name': 'Steve',
#    'link': 'https://stackoverflow.com/users/14157249/steve'},
#   'is_answered': False,
#   'view_count': 2,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1633155614,
#   'creation_date': 1633155614,
#   'question_id': 69414512,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/69414512/how-can-i-handle-jest-has-detected-the-following-open-handles-potentially-keepin',
#   'title': 'How can i handle jest has detected the following open handles potentially keeping Jest from exiting when using node-ftech'},
#  {'tags': ['node.js', 'reactjs', 'npm', 'publish', 'lint'],
#   'owner': {'account_id': 16270137,
#    'reputation': 1167,
#    'user_id': 11749004,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/f62bb8f1336b7417925747fcd790f5c0?s=128&d=identicon&r=PG&f=1',
#    'display_name': 'Kid',
#    'link': 'https://stackoverflow.com/users/11749004/kid'},
#   'is_answered': False,
#   'view_count': 23,
#   'answer_count': 0,
#   'score': 1,
#   'last_activity_date': 1633155614,
#   'creation_date': 1633121801,
#   'last_edit_date': 1633155614,
#   'question_id': 69411911,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/69411911/why-did-i-get-the-no-unused-expressions-error-on-npm-start-here-in-my-case',
#   'title': 'Why did I get the no-unused-expressions error on &quot;npm start&quot; here in my case'},
#  {'tags': ['java', 'mapping', 'mapstruct'],
#   'owner': {'account_id': 15292689,
#    'reputation': 1,
#    'user_id': 11033756,
#    'user_type': 'registered',
#    'profile_image': 'https://lh3.googleusercontent.com/-_jcx-Lxzj50/AAAAAAAAAAI/AAAAAAAAIuU/Vr2yxF4SauY/photo.jpg?sz=128',
#    'display_name': 'Silaghi Alexandru-Mihail',
#    'link': 'https://stackoverflow.com/users/11033756/silaghi-alexandru-mihail'},
#   'is_answered': False,
#   'view_count': 14,
#   'answer_count': 1,
#   'score': 0,
#   'last_activity_date': 1633155605,
#   'creation_date': 1632480629,
#   'question_id': 69313771,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/69313771/mapstruct-package-private-attributes',
#   'title': 'Mapstruct package private attributes'},
#  {'tags': ['javascript', 'node.js', 'cheerio'],
#   'owner': {'account_id': 13391178,
#    'reputation': 2691,
#    'user_id': 9663497,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/a2146a2188db75aa6c8d552e7804ea30?s=128&d=identicon&r=PG&f=1',
#    'display_name': 'Vincenzo',
#    'link': 'https://stackoverflow.com/users/9663497/vincenzo'},
#   'is_answered': False,
#   'view_count': 11,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1633155582,
#   'creation_date': 1633152100,
#   'last_edit_date': 1633155582,
#   'question_id': 69414213,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/69414213/typeerror-dom-getelementsbytagname-is-not-a-function-node-js',
#   'title': 'TypeError: dom.getElementsByTagName is not a function Node.js'},
#  {'tags': ['ios', 'xcode', 'icons', 'tabview', 'sf-symbols'],
#   'owner': {'account_id': 11987709,
#    'reputation': 373,
#    'user_id': 8771798,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/d8c740e16aca1e8a49b063e3762ca4ef?s=128&d=identicon&r=PG&f=1',
#    'display_name': 'Flincorp',
#    'link': 'https://stackoverflow.com/users/8771798/flincorp'},
#   'is_answered': False,
#   'view_count': 43,
#   'answer_count': 1,
#   'score': 1,
#   'last_activity_date': 1633155566,
#   'creation_date': 1632507584,
#   'question_id': 69319575,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/69319575/how-to-change-filled-icon-to-not-filled-on-tabview-tabitem-in-ios-15-xcode-13',
#   'title': 'How to change filled icon to not filled on TabView tabItem in iOS 15 Xcode 13?'},
#  {'tags': ['python'],
#   'owner': {'account_id': 22248294,
#    'reputation': 1,
#    'user_id': 16481640,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/73ebd3a4485cd80d9ce0ebc8a41aba10?s=128&d=identicon&r=PG&f=1',
#    'display_name': 'AdityaCodes',
#    'link': 'https://stackoverflow.com/users/16481640/adityacodes'},
#   'is_answered': False,
#   'view_count': 4,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1633155563,
#   'creation_date': 1633155563,
#   'question_id': 69414509,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/69414509/having-a-problem-in-python-showing-error-can-only-concatenate-str-not-bool',
#   'title': 'Having a problem in python: Showing error can only concatenate str (not &quot;bool&quot;) to str'},
#  {'tags': ['python', 'pyqt5', 'icons', 'qfiledialog'],
#   'owner': {'account_id': 18802257,
#    'reputation': 1,
#    'user_id': 13712328,
#    'user_type': 'registered',
#    'profile_image': 'https://lh3.googleusercontent.com/a-/AOh14GhIfQwyZE_YhsMhw-AHgpvYPB5XCbd6gLofWv3d=k-s128',
#    'display_name': 'sana sm',
#    'link': 'https://stackoverflow.com/users/13712328/sana-sm'},
#   'is_answered': False,
#   'view_count': 21,
#   'closed_date': 1632759677,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1633155562,
#   'creation_date': 1632736379,
#   'last_edit_date': 1633155562,
#   'question_id': 69344641,
#   'link': 'https://stackoverflow.com/questions/69344641/set-icon-when-saving-file-in-pyqt5',
#   'closed_reason': 'Needs details or clarity',
#   'title': 'set icon when saving file in pyqt5'},
#  {'tags': ['java'],
#   'owner': {'account_id': 5672211,
#    'reputation': 4058,
#    'user_id': 4969916,
#    'user_type': 'registered',
#    'accept_rate': 35,
#    'profile_image': 'https://lh6.googleusercontent.com/-QNfz4LV_I8A/AAAAAAAAAAI/AAAAAAAAAD0/lvTyKboHs6s/photo.jpg?sz=128',
#    'display_name': 'Shiladittya Chakraborty',
#    'link': 'https://stackoverflow.com/users/4969916/shiladittya-chakraborty'},
#   'is_answered': False,
#   'view_count': 35,
#   'answer_count': 2,
#   'score': 0,
#   'last_activity_date': 1633155554,
#   'creation_date': 1633151930,
#   'question_id': 69414200,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/69414200/remove-data-from-one-list-with-another-list-data-function-not-working-properly',
#   'title': 'remove data from one list with another list data function not working properly'},
#  {'tags': ['java', 'eclipse', 'while-loop', 'syntax', 'integer'],
#   'owner': {'account_id': 22920572,
#    'reputation': 1,
#    'user_id': 17056464,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/1afc1eba6030118e32ddab86e942cb52?s=128&d=identicon&r=PG',
#    'display_name': 'Sridevi',
#    'link': 'https://stackoverflow.com/users/17056464/sridevi'},
#   'is_answered': False,
#   'view_count': 4,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1633155545,
#   'creation_date': 1633155545,
#   'question_id': 69414508,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/69414508/why-it-is-showing-syntax-error-like-syntax-error-on-token-class-invalid-expr',
#   'title': 'why it is showing syntax error like &quot;Syntax error on token &quot;class&quot;, invalid Expression&quot;'},
#  {'tags': ['python', 'macos', 'jupyter-notebook', 'plaidml'],
#   'owner': {'account_id': 17775293,
#    'reputation': 9,
#    'user_id': 12907797,
#    'user_type': 'registered',
#    'profile_image': 'https://graph.facebook.com/3261884620492353/picture?type=large',
#    'display_name': 'I-Fan Lin',
#    'link': 'https://stackoverflow.com/users/12907797/i-fan-lin'},
#   'is_answered': False,
#   'view_count': 50,
#   'answer_count': 1,
#   'score': 0,
#   'last_activity_date': 1633155545,
#   'creation_date': 1620146760,
#   'question_id': 67388836,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/67388836/i-used-plaidml-in-python-but-my-gpu-did-not-run-i-use-macbook-pro-16-2019',
#   'title': 'I used plaidml in python but my GPU did not run. ( I use Macbook Pro 16, 2019)'},
#  {'tags': ['javascript'],
#   'owner': {'account_id': 22833137,
#    'reputation': 9,
#    'user_id': 16981270,
#    'user_type': 'registered',
#    'profile_image': 'https://lh3.googleusercontent.com/a/AATXAJx71xZZwRa12RZjdISEUgtmQL45QuLR7Xa8pqpX=k-s128',
#    'display_name': 'Milton T',
#    'link': 'https://stackoverflow.com/users/16981270/milton-t'},
#   'is_answered': True,
#   'view_count': 70,
#   'accepted_answer_id': 69413811,
#   'answer_count': 5,
#   'score': -1,
#   'last_activity_date': 1633155541,
#   'creation_date': 1633141384,
#   'last_edit_date': 1633142440,
#   'question_id': 69413520,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/69413520/automatically-remove-a-div-with-javascript',
#   'title': 'automatically remove a div with javascript'},
#  {'tags': ['python', 'sum'],
#   'owner': {'account_id': 22874295,
#    'reputation': 1,
#    'user_id': 17016873,
#    'user_type': 'registered',
#    'profile_image': 'https://lh3.googleusercontent.com/a/AATXAJwozMar6qxCh7KG-nWfVB0yTwzbCf_I1ylU70Bp=k-s128',
#    'display_name': 'sunday rose',
#    'link': 'https://stackoverflow.com/users/17016873/sunday-rose'},
#   'is_answered': False,
#   'view_count': 35,
#   'answer_count': 3,
#   'score': -1,
#   'last_activity_date': 1633155540,
#   'creation_date': 1633154344,
#   'last_edit_date': 1633154661,
#   'question_id': 69414399,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/69414399/what-is-wrong-in-this-python-code-i-want-to-return-the-sum-of-digits-ex-123',
#   'title': 'What is wrong in this python code? I want to return the sum of digits, Ex. 123 == 1+2+3 = 6 using sum() function in python?'},
#  {'tags': ['excel', 'vba'],
#   'owner': {'account_id': 22919346,
#    'reputation': 1,
#    'user_id': 17055408,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/942f37c2b7e05f60a1980741688bc609?s=128&d=identicon&r=PG',
#    'display_name': 'berclaw',
#    'link': 'https://stackoverflow.com/users/17055408/berclaw'},
#   'is_answered': False,
#   'view_count': 18,
#   'answer_count': 1,
#   'score': 0,
#   'last_activity_date': 1633155535,
#   'creation_date': 1633144447,
#   'question_id': 69413690,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/69413690/trying-to-loop-through-files-and-copy-an-array-of-sheets-using-vba-getting-erro',
#   'title': 'Trying to loop through files and copy an array of sheets using VBA, getting Error 424 Object Required'},
#  {'tags': ['matlab'],
#   'owner': {'account_id': 17753836,
#    'reputation': 79,
#    'user_id': 12893769,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/5b9e2feba94547f07ad99f697d6d4946?s=128&d=identicon&r=PG&f=1',
#    'display_name': 'alirazi',
#    'link': 'https://stackoverflow.com/users/12893769/alirazi'},
#   'is_answered': False,
#   'view_count': 3,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1633155533,
#   'creation_date': 1633155533,
#   'question_id': 69414506,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/69414506/merge-strings-and-table-to-one-text-file-using-fprintf-matlab',
#   'title': 'Merge strings and table to one text file using fprintf - Matlab'},
#  {'tags': ['c++', 'parameter-pack'],
#   'owner': {'account_id': 20404882,
#    'reputation': 1,
#    'user_id': 14969712,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/e7f20223ff6729361c60034dc31acb5b?s=128&d=identicon&r=PG&f=1',
#    'display_name': 'GGeorge',
#    'link': 'https://stackoverflow.com/users/14969712/ggeorge'},
#   'is_answered': False,
#   'view_count': 24,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1633155528,
#   'creation_date': 1633149204,
#   'last_edit_date': 1633155528,
#   'question_id': 69413986,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/69413986/paramater-pack-extraction',
#   'title': 'Paramater pack extraction'},
#  {'tags': ['c', 'gcc', 'compilation', 'compiler-optimization'],
#   'owner': {'account_id': 10734102,
#    'reputation': 388,
#    'user_id': 7899226,
#    'user_type': 'registered',
#    'profile_image': 'https://lh6.googleusercontent.com/-ler-_6Kql0U/AAAAAAAAAAI/AAAAAAAAACY/ZJfWk7xOZPE/photo.jpg?sz=128',
#    'display_name': '0xF4D3C0D3',
#    'link': 'https://stackoverflow.com/users/7899226/0xf4d3c0d3'},
#   'is_answered': True,
#   'view_count': 33,
#   'answer_count': 2,
#   'score': 1,
#   'last_activity_date': 1633155528,
#   'creation_date': 1633150595,
#   'question_id': 69414094,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/69414094/gcc-optmizes-printf-to-puts-i-dont-want-that',
#   'title': 'gcc optmizes printf to puts. I don&#39;t want that'},
#  {'tags': ['vba', 'mailmerge'],
#   'owner': {'account_id': 15761061,
#    'reputation': 3,
#    'user_id': 11372761,
#    'user_type': 'registered',
#    'profile_image': 'https://lh4.googleusercontent.com/-x4PdSNOcXDk/AAAAAAAAAAI/AAAAAAAAKe4/SwuFKDe3Nlw/photo.jpg?sz=128',
#    'display_name': 'Shaf3067',
#    'link': 'https://stackoverflow.com/users/11372761/shaf3067'},
#   'is_answered': False,
#   'view_count': 2,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1633155524,
#   'creation_date': 1633155524,
#   'question_id': 69414504,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/69414504/mail-merge-document-group-by-and-save-in-one-pdf-format-as-per-the-employee',
#   'title': 'Mail Merge Document ..! group by and Save in one PDF format as per the Employee Name Like SMS Thread'},
#  {'tags': ['google-analytics', 'google-analytics-api'],
#   'owner': {'account_id': 313122,
#    'reputation': 283,
#    'user_id': 627582,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/a2f1245315981918934bcf988d319ef4?s=128&d=identicon&r=PG',
#    'display_name': 'pedroaxl',
#    'link': 'https://stackoverflow.com/users/627582/pedroaxl'},
#   'is_answered': True,
#   'view_count': 4771,
#   'accepted_answer_id': 32232244,
#   'answer_count': 2,
#   'score': 7,
#   'last_activity_date': 1633155512,
#   'creation_date': 1440607298,
#   'question_id': 32232169,
#   'content_license': 'CC BY-SA 3.0',
#   'link': 'https://stackoverflow.com/questions/32232169/daily-weekly-monthly-active-users-on-google-analytics-api',
#   'title': 'Daily/Weekly/Monthly Active Users on Google Analytics API'},
#  {'tags': ['visual-studio-code'],
#   'owner': {'account_id': 22920557,
#    'reputation': 1,
#    'user_id': 17056449,
#    'user_type': 'registered',
#    'profile_image': 'https://lh3.googleusercontent.com/a-/AOh14GiRqRvRr7wn75mqckXkjnMllSsqanh4cKcBfroleg=k-s128',
#    'display_name': 'Md Noorul Haque',
#    'link': 'https://stackoverflow.com/users/17056449/md-noorul-haque'},
#   'is_answered': False,
#   'view_count': 4,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1633155510,
#   'creation_date': 1633155510,
#   'question_id': 69414502,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/69414502/couldnt-start-client-azure-resource-manager-template-in-vs-code',
#   'title': 'Couldn&#39;t start client Azure Resource Manager Template in VS Code'},
#  {'tags': ['r', 'regex', 'tidyr'],
#   'owner': {'account_id': 22308983,
#    'reputation': 13,
#    'user_id': 16533236,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/b3f9489b7d31f9e942d6c25fdc19a104?s=128&d=identicon&r=PG&f=1',
#    'display_name': 'Hi_Viz',
#    'link': 'https://stackoverflow.com/users/16533236/hi-viz'},
#   'is_answered': False,
#   'view_count': 11,
#   'answer_count': 1,
#   'score': 0,
#   'last_activity_date': 1633155506,
#   'creation_date': 1633154528,
#   'question_id': 69414414,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/69414414/pivot-longer-with-regex-for-two-digit-numbers-in-names-pattern',
#   'title': 'Pivot_longer with regex for two-digit numbers in names_pattern'},
#  {'tags': ['java', 'netbeans', 'jframe', 'netbeans-12'],
#   'owner': {'account_id': 22880973,
#    'reputation': 3,
#    'user_id': 17022570,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/dbba86cb130e9069b649377474b56f75?s=128&d=identicon&r=PG',
#    'display_name': 'JFan',
#    'link': 'https://stackoverflow.com/users/17022570/jfan'},
#   'is_answered': False,
#   'view_count': 5,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1633155493,
#   'creation_date': 1633155493,
#   'question_id': 69414500,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/69414500/netbeans-gui-builder-from-existing-file',
#   'title': 'NetBeans GUI Builder from existing file'},
#  {'tags': ['django-models', 'django-views', 'django-templates'],
#   'owner': {'account_id': 22845637,
#    'reputation': 3,
#    'user_id': 16992014,
#    'user_type': 'registered',
#    'profile_image': 'https://lh3.googleusercontent.com/a-/AOh14GjlAAWimvUfTbr-Uj82uUq9PudgjVHvz1IHRrJAAQ=k-s128',
#    'display_name': 'Ashok shah',
#    'link': 'https://stackoverflow.com/users/16992014/ashok-shah'},
#   'is_answered': False,
#   'view_count': 7,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1633155490,
#   'creation_date': 1633154502,
#   'last_edit_date': 1633155490,
#   'question_id': 69414411,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/69414411/hi-i-want-to-display-dynamic-data-first-row-is-in-6-columns-other-is-col-3-col',
#   'title': 'Hi, I want to display dynamic data, First row is in 6 columns other is col-3 col-3'},
#  {'tags': ['python', 'algorithm', 'encryption', 'hash'],
#   'owner': {'account_id': 8921343,
#    'reputation': 2397,
#    'user_id': 8124392,
#    'user_type': 'registered',
#    'accept_rate': 94,
#    'profile_image': 'https://www.gravatar.com/avatar/29ccdaed954c2c2d9da35fcefcadcb95?s=128&d=identicon&r=PG&f=1',
#    'display_name': 'oo92',
#    'link': 'https://stackoverflow.com/users/8124392/oo92'},
#   'is_answered': False,
#   'view_count': 7,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1633155484,
#   'creation_date': 1633155484,
#   'question_id': 69414499,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/69414499/find-a-hash-encryption-input-from-an-output',
#   'title': 'Find a hash encryption input from an output'},
#  {'tags': ['for-loop'],
#   'owner': {'account_id': 22920424,
#    'reputation': 1,
#    'user_id': 17056338,
#    'user_type': 'registered',
#    'profile_image': 'https://lh3.googleusercontent.com/a/AATXAJwXCmCRNfZ-Yb4NGsmY27EaSIsAA5Ip7kx-ccquKg=k-s128',
#    'display_name': 'NurlanK',
#    'link': 'https://stackoverflow.com/users/17056338/nurlank'},
#   'is_answered': False,
#   'view_count': 10,
#   'answer_count': 1,
#   'score': 0,
#   'last_activity_date': 1633155482,
#   'creation_date': 1633153532,
#   'last_edit_date': 1633153841,
#   'question_id': 69414329,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/69414329/transcribing-for-loop-in-one-line-to-staircase-for-loop',
#   'title': 'Transcribing for-loop in one line to staircase for-loop'},
#  {'tags': ['sql', 'null', 'inner-join'],
#   'owner': {'account_id': 17767169,
#    'reputation': 1,
#    'user_id': 12901748,
#    'user_type': 'registered',
#    'profile_image': 'https://lh3.googleusercontent.com/a-/AAuE7mCVNixbfmAzC1qbts04qGJ0kIIhjYFqlhHy7dC3=k-s128',
#    'display_name': 'Shubham Londhe',
#    'link': 'https://stackoverflow.com/users/12901748/shubham-londhe'},
#   'is_answered': False,
#   'view_count': 10,
#   'answer_count': 1,
#   'score': -2,
#   'last_activity_date': 1633155472,
#   'creation_date': 1633154178,
#   'question_id': 69414382,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/69414382/how-to-write-sql-query-to-join-2-tables-with-common-column-and-fill-empty-row-by',
#   'title': 'how to write sql query to join 2 tables with common column and fill empty row by NULL keyword'},
#  {'tags': ['html', 'css'],
#   'owner': {'account_id': 20996859,
#    'reputation': 1,
#    'user_id': 15428493,
#    'user_type': 'registered',
#    'profile_image': 'https://graph.facebook.com/3154190068141214/picture?type=large',
#    'display_name': 'MatchaLattee',
#    'link': 'https://stackoverflow.com/users/15428493/matchalattee'},
#   'is_answered': False,
#   'view_count': 32,
#   'answer_count': 1,
#   'score': 0,
#   'last_activity_date': 1633155469,
#   'creation_date': 1633145113,
#   'last_edit_date': 1633155052,
#   'question_id': 69413741,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/69413741/how-do-i-fix-this-overflow-problem-when-using-hover-function',
#   'title': 'How do I fix this overflow problem when using hover function'},
#  {'tags': ['php'],
#   'owner': {'account_id': 22920592,
#    'reputation': 1,
#    'user_id': 17056483,
#    'user_type': 'registered',
#    'profile_image': 'https://lh3.googleusercontent.com/a-/AOh14GiZIEona0Sf9ocpU4PT3x_nzsi5_chXvEOEQFAoIA=k-s128',
#    'display_name': 'sasitharan sasi',
#    'link': 'https://stackoverflow.com/users/17056483/sasitharan-sasi'},
#   'is_answered': False,
#   'view_count': 7,
#   'answer_count': 0,
#   'score': -1,
#   'last_activity_date': 1633155460,
#   'creation_date': 1633155460,
#   'question_id': 69414495,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/69414495/how-to-add-an-blog-cms-in-an-existing-user-management-php-website',
#   'title': 'How to add an blog cms in an existing user management php website?'},
#  {'tags': ['javascript', 'reactjs', 'async-await', 'onclick', 'return'],
#   'owner': {'account_id': 18842021,
#    'reputation': 206,
#    'user_id': 13743242,
#    'user_type': 'registered',
#    'profile_image': 'https://i.stack.imgur.com/Vui01.jpg?s=128&g=1',
#    'display_name': 'Jesse G',
#    'link': 'https://stackoverflow.com/users/13743242/jesse-g'},
#   'is_answered': False,
#   'view_count': 6,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1633155458,
#   'creation_date': 1633155458,
#   'question_id': 69414494,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/69414494/how-can-i-use-an-async-function-to-await-for-an-onclick-event-choice-between',
#   'title': 'How can I use an async function to await for an onClick() event (Choice between 2 Buttons in a Modal)'},
#  {'tags': ['shell', 'find', 'sh', 'posix', 'nice'],
#   'owner': {'account_id': 4620617,
#    'reputation': 1798,
#    'user_id': 3745821,
#    'user_type': 'registered',
#    'profile_image': 'https://i.stack.imgur.com/DYzuR.jpg?s=128&g=1',
#    'display_name': 'Michael Back',
#    'link': 'https://stackoverflow.com/users/3745821/michael-back'},
#   'is_answered': False,
#   'view_count': 13,
#   'closed_date': 1633152227,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1633155458,
#   'creation_date': 1633150495,
#   'last_edit_date': 1633155458,
#   'question_id': 69414084,
#   'link': 'https://stackoverflow.com/questions/69414084/how-do-i-stop-find-from-outputting-error-in-posix-shell-driven-by-cron',
#   'closed_reason': 'Not suitable for this site',
#   'title': 'How do I stop &quot;find&quot; from outputting error in POSIX Shell driven by CRON?'},
#  {'tags': ['user-interface', 'testing', 'automation', 'automated-tests'],
#   'owner': {'account_id': 186,
#    'reputation': 27904,
#    'user_id': 230,
#    'user_type': 'registered',
#    'accept_rate': 54,
#    'profile_image': 'https://www.gravatar.com/avatar/decf93f3a084227668147039af95c302?s=128&d=identicon&r=PG',
#    'display_name': 'Dan',
#    'link': 'https://stackoverflow.com/users/230/dan'},
#   'is_answered': True,
#   'view_count': 22057,
#   'closed_date': 1365243646,
#   'accepted_answer_id': 805934,
#   'answer_count': 17,
#   'score': 33,
#   'last_activity_date': 1633155444,
#   'creation_date': 1241079798,
#   'last_edit_date': 1633155444,
#   'question_id': 805910,
#   'link': 'https://stackoverflow.com/questions/805910/what-is-the-best-automated-website-ui-testing-framework',
#   'closed_reason': 'not constructive',
#   'title': 'What is the best automated website UI testing framework'}]

# %%
# Number of elements in a List
print("Number of elements in the 'items' list is", len(response_json['items']))
# Out:
# Number of elements in the 'items' list is 30

# %% [markdown]
# ### 4. Paging

# %%
# Loop through pages in API

# Define page, pagesize and fromdate parameters for fetching pages of results from the API (according to StackExchange documentation)
page = 1
pagesize = 100
fromdate = 1633132800 # 02.10.2021

has_more = True

# Create empty List
total_results = []

while has_more:   
    # Define the url with page, pagesize and fromdate parameters
    url = f"https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page={page}&pagesize={pagesize}&fromdate={fromdate}"
    print("Requesting:", url)
    
    # Response object returned from the API
    response = requests.get(url)
    
    # JSON response of the JSON object of the result
    response_data = response.json()
    
    # Check if data in 'items' is present
    if len(response_data['items']) == 0:
        # If not, exit the loop
        break
    # If yes, then add the specified list elements (or any iterable) to the end of the current list in order to collect all API results into a List
    total_results.extend(response_data['items'])
    
    # Increaae the page number by 1
    page += 1
    
    # Halt the code execution (timeout for 3 seconds added to prevent rate-limiting)
    time.sleep(3)
# Out:
# Requesting: https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page=1&pagesize=100&fromdate=1633132800
# Requesting: https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page=2&pagesize=100&fromdate=1633132800
# Requesting: https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page=3&pagesize=100&fromdate=1633132800
# Requesting: https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page=4&pagesize=100&fromdate=1633132800
# Requesting: https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page=5&pagesize=100&fromdate=1633132800
# Requesting: https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page=6&pagesize=100&fromdate=1633132800
# Requesting: https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page=7&pagesize=100&fromdate=1633132800
# Requesting: https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page=8&pagesize=100&fromdate=1633132800
# Requesting: https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow&page=9&pagesize=100&fromdate=1633132800

# %%
# Number of elements in a List
print(len(total_results))
# Out:
# 753

# %% [markdown]
# ### 5. Add Data into Pandas DataFrame

# %% [markdown]
# #### using .DataFrame()

# %%
# Add Data into Pandas DataFrame
df = pd.DataFrame(total_results)

# %%
# Print out the Pandas DataFrame
print(df)
# Out:
#                                              tags  \
# 0          [node.js, typescript, testing, jestjs]
# 1                  [javascript, node.js, cheerio]
# 2                                        [python]
# 3                                          [java]
# 4    [java, eclipse, while-loop, syntax, integer]
# ..                                            ...
# 748    [splunk, splunk-query, splunk-calculation]
# 749     [gradle, build.gradle, gradle-kotlin-dsl]
# 750             [mysql, docker, pyspark, airflow]
# 751                              [c++, rapidjson]
# 752                                [r, stargazer]
#
#                                                  owner  is_answered  \
# 0    {'account_id': 19362206, 'reputation': 21, 'us...        False
# 1    {'account_id': 13391178, 'reputation': 2691, '...        False
# 2    {'account_id': 22248294, 'reputation': 1, 'use...        False
# 3    {'account_id': 5672211, 'reputation': 4058, 'u...        False
# 4    {'account_id': 22920572, 'reputation': 1, 'use...        False
# ..                                                 ...          ...
# 748  {'account_id': 3106206, 'reputation': 7429, 'u...        False
# 749  {'account_id': 15084680, 'reputation': 43, 'us...        False
# 750  {'account_id': 20840070, 'reputation': 1, 'use...        False
# 751  {'account_id': 6706810, 'reputation': 854, 'us...        False
# 752  {'account_id': 18443959, 'reputation': 29, 'us...        False
#
#      view_count  answer_count  score  last_activity_date  creation_date  \
# 0             2             0      0          1633155614     1633155614
# 1            11             0      0          1633155582     1633152100
# 2             4             0      0          1633155563     1633155563
# 3            35             2      0          1633155554     1633151930
# 4             4             0      0          1633155545     1633155545
# ..          ...           ...    ...                 ...            ...
# 748           7             0      0          1633133000     1633133000
# 749           5             0      0          1633132999     1633132999
# 750          13             0      0          1633132936     1633132936
# 751          14             0      0          1633132847     1633132847
# 752           7             0      0          1633132819     1633132819
#
#      question_id content_license  \
# 0       69414512    CC BY-SA 4.0
# 1       69414213    CC BY-SA 4.0
# 2       69414509    CC BY-SA 4.0
# 3       69414200    CC BY-SA 4.0
# 4       69414508    CC BY-SA 4.0
# ..           ...             ...
# 748     69412986    CC BY-SA 4.0
# 749     69412984    CC BY-SA 4.0
# 750     69412978    CC BY-SA 4.0
# 751     69412970    CC BY-SA 4.0
# 752     69412966    CC BY-SA 4.0
#
#                                                   link  \
# 0    https://stackoverflow.com/questions/69414512/h...
# 1    https://stackoverflow.com/questions/69414213/t...
# 2    https://stackoverflow.com/questions/69414509/h...
# 3    https://stackoverflow.com/questions/69414200/r...
# 4    https://stackoverflow.com/questions/69414508/w...
# ..                                                 ...
# 748  https://stackoverflow.com/questions/69412986/s...
# 749  https://stackoverflow.com/questions/69412984/g...
# 750  https://stackoverflow.com/questions/69412978/h...
# 751  https://stackoverflow.com/questions/69412970/a...
# 752  https://stackoverflow.com/questions/69412966/s...
#
#                                                  title  last_edit_date  \
# 0    How can i handle jest has detected the followi...             NaN
# 1    TypeError: dom.getElementsByTagName is not a f...    1.633156e+09
# 2    Having a problem in python: Showing error can ...             NaN
# 3    remove data from one list with another list da...             NaN
# 4    why it is showing syntax error like &quot;Synt...             NaN
# ..                                                 ...             ...
# 748                     Splunk Concurrency Calculation             NaN
# 749              gradlew kts multi project outrput jar             NaN
# 750        How to configure JAVA_HOME setup in airflow             NaN
# 751  arrays of arrays writing to a file using rapid...             NaN
# 752  Stargazer regression table not displaying basi...             NaN
#
#      accepted_answer_id  closed_date closed_reason
# 0                   NaN          NaN           NaN
# 1                   NaN          NaN           NaN
# 2                   NaN          NaN           NaN
# 3                   NaN          NaN           NaN
# 4                   NaN          NaN           NaN
# ..                  ...          ...           ...
# 748                 NaN          NaN           NaN
# 749                 NaN          NaN           NaN
# 750                 NaN          NaN           NaN
# 751                 NaN          NaN           NaN
# 752                 NaN          NaN           NaN
#
# [753 rows x 16 columns]

# %%
# Display the few top rows of Pandas DataFrame
df.head()
# Out:
#                                            tags  \
# 0        [node.js, typescript, testing, jestjs]
# 1                [javascript, node.js, cheerio]
# 2                                      [python]
# 3                                        [java]
# 4  [java, eclipse, while-loop, syntax, integer]
#
#                                                owner  is_answered  view_count  \
# 0  {'account_id': 19362206, 'reputation': 21, 'us...        False           2
# 1  {'account_id': 13391178, 'reputation': 2691, '...        False          11
# 2  {'account_id': 22248294, 'reputation': 1, 'use...        False           4
# 3  {'account_id': 5672211, 'reputation': 4058, 'u...        False          35
# 4  {'account_id': 22920572, 'reputation': 1, 'use...        False           4
#
#    answer_count  score  last_activity_date  creation_date  question_id  \
# 0             0      0          1633155614     1633155614     69414512
# 1             0      0          1633155582     1633152100     69414213
# 2             0      0          1633155563     1633155563     69414509
# 3             2      0          1633155554     1633151930     69414200
# 4             0      0          1633155545     1633155545     69414508
#
#   content_license                                               link  \
# 0    CC BY-SA 4.0  https://stackoverflow.com/questions/69414512/h...
# 1    CC BY-SA 4.0  https://stackoverflow.com/questions/69414213/t...
# 2    CC BY-SA 4.0  https://stackoverflow.com/questions/69414509/h...
# 3    CC BY-SA 4.0  https://stackoverflow.com/questions/69414200/r...
# 4    CC BY-SA 4.0  https://stackoverflow.com/questions/69414508/w...
#
#                                                title  last_edit_date  \
# 0  How can i handle jest has detected the followi...             NaN
# 1  TypeError: dom.getElementsByTagName is not a f...    1.633156e+09
# 2  Having a problem in python: Showing error can ...             NaN
# 3  remove data from one list with another list da...             NaN
# 4  why it is showing syntax error like &quot;Synt...             NaN
#
#    accepted_answer_id  closed_date closed_reason
# 0                 NaN          NaN           NaN
# 1                 NaN          NaN           NaN
# 2                 NaN          NaN           NaN
# 3                 NaN          NaN           NaN
# 4                 NaN          NaN           NaN

# %%
# Display the few last rows of Pandas DataFrame
df.tail()
# Out:
#                                            tags  \
# 748  [splunk, splunk-query, splunk-calculation]
# 749   [gradle, build.gradle, gradle-kotlin-dsl]
# 750           [mysql, docker, pyspark, airflow]
# 751                            [c++, rapidjson]
# 752                              [r, stargazer]
#
#                                                  owner  is_answered  \
# 748  {'account_id': 3106206, 'reputation': 7429, 'u...        False
# 749  {'account_id': 15084680, 'reputation': 43, 'us...        False
# 750  {'account_id': 20840070, 'reputation': 1, 'use...        False
# 751  {'account_id': 6706810, 'reputation': 854, 'us...        False
# 752  {'account_id': 18443959, 'reputation': 29, 'us...        False
#
#      view_count  answer_count  score  last_activity_date  creation_date  \
# 748           7             0      0          1633133000     1633133000
# 749           5             0      0          1633132999     1633132999
# 750          13             0      0          1633132936     1633132936
# 751          14             0      0          1633132847     1633132847
# 752           7             0      0          1633132819     1633132819
#
#      question_id content_license  \
# 748     69412986    CC BY-SA 4.0
# 749     69412984    CC BY-SA 4.0
# 750     69412978    CC BY-SA 4.0
# 751     69412970    CC BY-SA 4.0
# 752     69412966    CC BY-SA 4.0
#
#                                                   link  \
# 748  https://stackoverflow.com/questions/69412986/s...
# 749  https://stackoverflow.com/questions/69412984/g...
# 750  https://stackoverflow.com/questions/69412978/h...
# 751  https://stackoverflow.com/questions/69412970/a...
# 752  https://stackoverflow.com/questions/69412966/s...
#
#                                                  title  last_edit_date  \
# 748                     Splunk Concurrency Calculation             NaN
# 749              gradlew kts multi project outrput jar             NaN
# 750        How to configure JAVA_HOME setup in airflow             NaN
# 751  arrays of arrays writing to a file using rapid...             NaN
# 752  Stargazer regression table not displaying basi...             NaN
#
#      accepted_answer_id  closed_date closed_reason
# 748                 NaN          NaN           NaN
# 749                 NaN          NaN           NaN
# 750                 NaN          NaN           NaN
# 751                 NaN          NaN           NaN
# 752                 NaN          NaN           NaN

# %% [markdown]
# ### 6. Pandas DataFrame to .csv file

# %%
# Write Pandas DataFrame to .csv file
df.to_csv('C:/Users/Administrator/Desktop/Data Engineer/stack_exchange_questions.csv', index = False)
